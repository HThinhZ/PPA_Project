# %% [markdown]
# <a href="https://colab.research.google.com/github/HThinhZ/PPA_Project/blob/main/PPA_Project_Final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Parallel Programming Application Project:**
# # **Parallel KMeans: Credit Card Segmentation**

# %% [markdown]
# > # *1. Giới thiệu:*

# %% [markdown]
# > ## **Thông tin nhóm:**

# %% [markdown]
# | MSSV     | Họ và tên             | Email    |
# | :-----:  | :--------:            | :-------:|
# | 20120481 | Phan Xuân Hoài        | 20120481@student.hcmus.edu.vn|
# | 20120587 | Nguyễn Hoàng Thịnh    | 20120587@student.hcmus.edu.vn|

# %% [markdown]
# > ## **Mô tả bài toán:**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Quy trình thực hiện chi tiết của thuật toán KMeans:
#
# + Bước 1: Khởi tạo các điểm trung tâm ban đầu
#   + Chọn số lượng cụm cần phân chia (k).
#   + Khởi tạo ngẫu nhiên k điểm dữ liệu từ tập dữ liệu ban đầu làm các điểm trung tâm ban đầu (centers) của các cụm. (Ở đây nhóm em lấy k điểm dữ liệu đầu tiên trong bộ dữ liệu)
# + Bước 2: Phân loại các điểm dữ liệu vào các cụm **(Song Song)**
#   + Tính toán khoảng cách (Sử dụng khoảng cách Euclide) giữa mỗi điểm dữ liệu và tất cả các điểm trung tâm.
#   + Gán mỗi điểm dữ liệu vào cụm có điểm trung tâm gần nhất.
# + Bước 3: Cập nhật vị trí của các điểm trung tâm **(Song Song)**
#   + Tính toán lại vị trí của các điểm trung tâm bằng cách lấy trung bình của tất cả các điểm dữ liệu trong cùng một cụm.
# + Bước 4: Lặp lại các bước 2 và 3
#   + Lặp lại các bước 2 và 3 cho đến khi không có sự thay đổi nào trong vị trí của các điểm trung tâm hoặc sau một số lần lặp cố định.
# + Bước 5: Kết thúc và đánh giá kết quả
#   + Kết thúc vòng lặp ta sẽ thu được số lượng cụm dữ liệu với mỗi cụm dữ liệu có nét tương đồng với nhau

# %% [markdown]
# > # *2. Thực hiện đồ án:*

# %% [markdown]
# > ## **Install và import thư viện**

# %%
# Install libraries

# %%
# Import libraries
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.metrics import davies_bouldin_score, silhouette_score, calinski_harabasz_score
import math
from numba import cuda, prange, jit
import numba
import warnings
warnings.filterwarnings(action="ignore")

# %%
# bảng thời gian
all_results = pd.DataFrame(columns=['time (s)'], dtype=float)
all_results
# Out:
# Empty DataFrame
# Columns: [time (s)]
# Index: []

# %% [markdown]
# > ## **Đọc dữ liệu:**

# %%
# !gdown https://drive.google.com/uc?id=1h4lv63HGrChaguGwtNtCYb7WPgb1Qnw3
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1h4lv63HGrChaguGwtNtCYb7WPgb1Qnw3
# To: /content/CC GENERAL.csv
# 100% 903k/903k [00:00<00:00, 96.7MB/s]

# %%
df = pd.read_csv("CC GENERAL.csv")
df
# Out:
#      CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0     C10001    40.900749           0.818182      95.40              0.00
# 1     C10002  3202.467416           0.909091       0.00              0.00
# 2     C10003  2495.148862           1.000000     773.17            773.17
# 3     C10004  1666.670542           0.636364    1499.00           1499.00
# 4     C10005   817.714335           1.000000      16.00             16.00
# ...      ...          ...                ...        ...               ...
# 8945  C19186    28.493517           1.000000     291.12              0.00
# 8946  C19187    19.183215           1.000000     300.00              0.00
# 8947  C19188    23.398673           0.833333     144.40              0.00
# 8948  C19189    13.457564           0.833333       0.00              0.00
# 8949  C19190   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                      95.40      0.000000             0.166667
# 1                       0.00   6442.945483             0.000000
# 2                       0.00      0.000000             1.000000
# 3                       0.00    205.788017             0.083333
# 4                       0.00      0.000000             0.083333
# ...                      ...           ...                  ...
# 8945                  291.12      0.000000             1.000000
# 8946                  300.00      0.000000             1.000000
# 8947                  144.40      0.000000             0.833333
# 8948                    0.00     36.558778             0.000000
# 8949                    0.00    127.040008             0.666667
#
#       ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                       0.000000                          0.083333
# 1                       0.000000                          0.000000
# 2                       1.000000                          0.000000
# 3                       0.083333                          0.000000
# 4                       0.083333                          0.000000
# ...                          ...                               ...
# 8945                    0.000000                          0.833333
# 8946                    0.000000                          0.833333
# 8947                    0.000000                          0.666667
# 8948                    0.000000                          0.000000
# 8949                    0.666667                          0.000000
#
#       CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 0                   0.000000                 0              2        1000.0
# 1                   0.250000                 4              0        7000.0
# 2                   0.000000                 0             12        7500.0
# 3                   0.083333                 1              1        7500.0
# 4                   0.000000                 0              1        1200.0
# ...                      ...               ...            ...           ...
# 8945                0.000000                 0              6        1000.0
# 8946                0.000000                 0              6        1000.0
# 8947                0.000000                 0              5        1000.0
# 8948                0.166667                 2              0         500.0
# 8949                0.333333                 2             23        1200.0
#
#          PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE
# 0      201.802084        139.509787          0.000000      12
# 1     4103.032597       1072.340217          0.222222      12
# 2      622.066742        627.284787          0.000000      12
# 3        0.000000               NaN          0.000000      12
# 4      678.334763        244.791237          0.000000      12
# ...           ...               ...               ...     ...
# 8945   325.594462         48.886365          0.500000       6
# 8946   275.861322               NaN          0.000000       6
# 8947    81.270775         82.418369          0.250000       6
# 8948    52.549959         55.755628          0.250000       6
# 8949    63.165404         88.288956          0.000000       6
#
# [8950 rows x 18 columns]

# %% [markdown]
# > ## **Khám phá dữ liệu**

# %% [markdown]
# ### 1. Thông tin cơ bản

# %%
# Data shape
df.shape
# Out:
# (8950, 18)

# %%
# Xem thông tin của dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8950 entries, 0 to 8949
# Data columns (total 18 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   CUST_ID                           8950 non-null   object
#  1   BALANCE                           8950 non-null   float64
#  2   BALANCE_FREQUENCY                 8950 non-null   float64
#  3   PURCHASES                         8950 non-null   float64
#  4   ONEOFF_PURCHASES                  8950 non-null   float64
#  5   INSTALLMENTS_PURCHASES            8950 non-null   float64
#  6   CASH_ADVANCE                      8950 non-null   float64
#  7   PURCHASES_FREQUENCY               8950 non-null   float64
#  8   ONEOFF_PURCHASES_FREQUENCY        8950 non-null   float64
#  9   PURCHASES_INSTALLMENTS_FREQUENCY  8950 non-null   float64
#  10  CASH_ADVANCE_FREQUENCY            8950 non-null   float64
#  11  CASH_ADVANCE_TRX                  8950 non-null   int64
#  12  PURCHASES_TRX                     8950 non-null   int64
#  13  CREDIT_LIMIT                      8949 non-null   float64
#  14  PAYMENTS                          8950 non-null   float64
#  15  MINIMUM_PAYMENTS                  8637 non-null   float64
#  16  PRC_FULL_PAYMENT                  8950 non-null   float64
#  17  TENURE                            8950 non-null   int64
# dtypes: float64(14), int64(3), object(1)
# memory usage: 1.2+ MB

# %% [markdown]
# #### **Nhận xét:**
# Customer ID nên được xóa bỏ vì không phù hợp cho việc phân cụm (KMeans)

# %%
df.describe()
# Out:
#             BALANCE  BALANCE_FREQUENCY     PURCHASES  ONEOFF_PURCHASES  \
# count   8950.000000        8950.000000   8950.000000       8950.000000
# mean    1564.474828           0.877271   1003.204834        592.437371
# std     2081.531879           0.236904   2136.634782       1659.887917
# min        0.000000           0.000000      0.000000          0.000000
# 25%      128.281915           0.888889     39.635000          0.000000
# 50%      873.385231           1.000000    361.280000         38.000000
# 75%     2054.140036           1.000000   1110.130000        577.405000
# max    19043.138560           1.000000  49039.570000      40761.250000
#
#        INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# count             8950.000000   8950.000000          8950.000000
# mean               411.067645    978.871112             0.490351
# std                904.338115   2097.163877             0.401371
# min                  0.000000      0.000000             0.000000
# 25%                  0.000000      0.000000             0.083333
# 50%                 89.000000      0.000000             0.500000
# 75%                468.637500   1113.821139             0.916667
# max              22500.000000  47137.211760             1.000000
#
#        ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# count                 8950.000000                       8950.000000
# mean                     0.202458                          0.364437
# std                      0.298336                          0.397448
# min                      0.000000                          0.000000
# 25%                      0.000000                          0.000000
# 50%                      0.083333                          0.166667
# 75%                      0.300000                          0.750000
# max                      1.000000                          1.000000
#
#        CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# count             8950.000000       8950.000000    8950.000000   8949.000000
# mean                 0.135144          3.248827      14.709832   4494.449450
# std                  0.200121          6.824647      24.857649   3638.815725
# min                  0.000000          0.000000       0.000000     50.000000
# 25%                  0.000000          0.000000       1.000000   1600.000000
# 50%                  0.000000          0.000000       7.000000   3000.000000
# 75%                  0.222222          4.000000      17.000000   6500.000000
# max                  1.500000        123.000000     358.000000  30000.000000
#
#            PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT       TENURE
# count   8950.000000       8637.000000       8950.000000  8950.000000
# mean    1733.143852        864.206542          0.153715    11.517318
# std     2895.063757       2372.446607          0.292499     1.338331
# min        0.000000          0.019163          0.000000     6.000000
# 25%      383.276166        169.123707          0.000000    12.000000
# 50%      856.901546        312.343947          0.000000    12.000000
# 75%     1901.134317        825.485459          0.142857    12.000000
# max    50721.483360      76406.207520          1.000000    12.000000

# %% [markdown]
# ### 2. Data Schema

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 3. Kiếm tra những thông tin cần tiền xử lý

# %%
# Ta thấy ở df.info() có những cột có giá trị Nan, kiểm tra:
df.isnull().sum()
# Out:
# CUST_ID                               0
# BALANCE                               0
# BALANCE_FREQUENCY                     0
# PURCHASES                             0
# ONEOFF_PURCHASES                      0
# INSTALLMENTS_PURCHASES                0
# CASH_ADVANCE                          0
# PURCHASES_FREQUENCY                   0
# ONEOFF_PURCHASES_FREQUENCY            0
# PURCHASES_INSTALLMENTS_FREQUENCY      0
# CASH_ADVANCE_FREQUENCY                0
# CASH_ADVANCE_TRX                      0
# PURCHASES_TRX                         0
# CREDIT_LIMIT                          1
# PAYMENTS                              0
# MINIMUM_PAYMENTS                    313
# PRC_FULL_PAYMENT                      0
# TENURE                                0
# dtype: int64

# %%
## Cột "CREDIT_LIMIT"
df[df["CREDIT_LIMIT"].isnull()]
# Out:
#      CUST_ID    BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 5203  C15349  18.400472           0.166667        0.0               0.0
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 5203                     0.0    186.853063                  0.0
#
#       ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 5203                         0.0                               0.0
#
#       CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 5203                0.166667                 1              0           NaN
#
#       PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE
# 5203  9.040017         14.418723               0.0       6

# %%
## Cột "MINIMUM_PAYMENTS"
df[df["MINIMUM_PAYMENTS"].isnull()]
# Out:
#      CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 3     C10004  1666.670542           0.636364    1499.00           1499.00
# 45    C10047  2242.311686           1.000000     437.00             97.00
# 47    C10049  3910.111237           1.000000       0.00              0.00
# 54    C10056     6.660517           0.636364     310.00              0.00
# 55    C10057  1311.995984           1.000000    1283.90           1283.90
# ...      ...          ...                ...        ...               ...
# 8919  C19160    14.524779           0.333333     152.00            152.00
# 8929  C19170   371.527312           0.333333       0.00              0.00
# 8935  C19176   183.817004           1.000000     465.90              0.00
# 8944  C19185   193.571722           0.833333    1012.73           1012.73
# 8946  C19187    19.183215           1.000000     300.00              0.00
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 3                        0.0    205.788017             0.083333
# 45                     340.0    184.648692             0.333333
# 47                       0.0   1980.873201             0.000000
# 54                     310.0      0.000000             0.666667
# 55                       0.0      0.000000             0.250000
# ...                      ...           ...                  ...
# 8919                     0.0      0.000000             0.333333
# 8929                     0.0   1465.407927             0.000000
# 8935                   465.9      0.000000             1.000000
# 8944                     0.0      0.000000             0.333333
# 8946                   300.0      0.000000             1.000000
#
#       ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 3                       0.083333                          0.000000
# 45                      0.083333                          0.333333
# 47                      0.000000                          0.000000
# 54                      0.000000                          0.666667
# 55                      0.250000                          0.000000
# ...                          ...                               ...
# 8919                    0.333333                          0.000000
# 8929                    0.000000                          0.000000
# 8935                    0.000000                          0.833333
# 8944                    0.333333                          0.000000
# 8946                    0.000000                          0.833333
#
#       CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 3                   0.083333                 1              1        7500.0
# 45                  0.166667                 2              5        2400.0
# 47                  0.500000                 7              0        4200.0
# 54                  0.000000                 0              8        1000.0
# 55                  0.000000                 0              6        6000.0
# ...                      ...               ...            ...           ...
# 8919                0.000000                 0              2        1500.0
# 8929                0.166667                 5              0        1500.0
# 8935                0.000000                 0              6        1500.0
# 8944                0.000000                 0              2        4000.0
# 8946                0.000000                 0              6        1000.0
#
#         PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE
# 3       0.000000               NaN               0.0      12
# 45      0.000000               NaN               0.0      12
# 47      0.000000               NaN               0.0      12
# 54    417.016763               NaN               0.0      12
# 55      0.000000               NaN               0.0      12
# ...          ...               ...               ...     ...
# 8919    0.000000               NaN               0.0       6
# 8929    0.000000               NaN               0.0       6
# 8935    0.000000               NaN               0.0       6
# 8944    0.000000               NaN               0.0       6
# 8946  275.861322               NaN               0.0       6
#
# [313 rows x 18 columns]

# %%
# Kiểm tra tính trùng lặp
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [CUST_ID, BALANCE, BALANCE_FREQUENCY, PURCHASES, ONEOFF_PURCHASES, INSTALLMENTS_PURCHASES, CASH_ADVANCE, PURCHASES_FREQUENCY, ONEOFF_PURCHASES_FREQUENCY, PURCHASES_INSTALLMENTS_FREQUENCY, CASH_ADVANCE_FREQUENCY, CASH_ADVANCE_TRX, PURCHASES_TRX, CREDIT_LIMIT, PAYMENTS, MINIMUM_PAYMENTS, PRC_FULL_PAYMENT, TENURE]
# Index: []

# %% [markdown]
# ### 4. Kiểm tra các outliers

# %%
plt.scatter(df["BALANCE"], df["BALANCE_FREQUENCY"], edgecolors="white")

# %%
plt.scatter(df["PAYMENTS"], df["PURCHASES"], edgecolors="white")

# %%
plt.scatter(df["CREDIT_LIMIT"], df["PURCHASES"], edgecolors="white")

# %%
plt.scatter(df["TENURE"], df["CREDIT_LIMIT"], edgecolors="white")

# %% [markdown]
# #### **Nhận xét:**

# %%
columns=['BALANCE', 'PURCHASES', 'ONEOFF_PURCHASES', 'INSTALLMENTS_PURCHASES',
         'CASH_ADVANCE', 'CREDIT_LIMIT',
        'PAYMENTS', 'MINIMUM_PAYMENTS']

for c in columns:
    df_table = df[c].copy()
    Q1 = df_table.quantile(0.25)
    Q3 = df_table.quantile(0.75)
    IQR = Q3 - Q1

    lower_bound = Q1 - 1.5*IQR
    upper_bound = Q1 + 1.5*IQR

    outliers_number = (( df_table < (lower_bound)) | (df_table > (upper_bound))).sum()
    outliers_number

    print("\n" + c)
    print("lower_bound is " + str(lower_bound))
    print("upper_bound is " + str(upper_bound))
    print("Q1 is : " + str(Q1))
    print("Q3 is : " + str(Q3))

    percentage = round((100*outliers_number) / (len(df_table)),2)
    print(str(outliers_number) + " of " + str(len(df_table)) + " is outlier (%" + str(percentage) + ")")
# Out:
# BALANCE
# lower_bound is -2760.5052645
# upper_bound is 3017.0690955000005
# Q1 is : 128.2819155
# Q3 is : 2054.1400355
# 1434 of 8950 is outlier (%16.02)
#
# PURCHASES
# lower_bound is -1566.1075000000003
# upper_bound is 1645.3775000000003
# Q1 is : 39.635
# Q3 is : 1110.13
# 1539 of 8950 is outlier (%17.2)
#
# ONEOFF_PURCHASES
# lower_bound is -866.1075
# upper_bound is 866.1075
# Q1 is : 0.0
# Q3 is : 577.405
# 1703 of 8950 is outlier (%19.03)
#
# INSTALLMENTS_PURCHASES
# lower_bound is -702.95625
# upper_bound is 702.95625
# Q1 is : 0.0
# Q3 is : 468.6375
# 1561 of 8950 is outlier (%17.44)
#
# CASH_ADVANCE
# lower_bound is -1670.7317088750003
# upper_bound is 1670.7317088750003
# Q1 is : 0.0
# Q3 is : 1113.8211392500002
# 1717 of 8950 is outlier (%19.18)
#
# CREDIT_LIMIT
# lower_bound is -5750.0
# upper_bound is 8950.0
# Q1 is : 1600.0
# Q3 is : 6500.0
# 1129 of 8950 is outlier (%12.61)
#
# PAYMENTS
# lower_bound is -1893.5110601250003
# upper_bound is 2660.0633921250005
# Q1 is : 383.276166
# Q3 is : 1901.1343167500002
# 1512 of 8950 is outlier (%16.89)
#
# MINIMUM_PAYMENTS
# lower_bound is -815.4189210000001
# upper_bound is 1153.6663350000001
# Q1 is : 169.123707
# Q3 is : 825.485459
# 1518 of 8950 is outlier (%16.96)

# %% [markdown]
# > ## **Tiền xử lý dữ liệu**

# %%
# Drop column CUST_ID
data = df.iloc[:,1:]
data.head()
# Out:
#        BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0    40.900749           0.818182      95.40              0.00
# 1  3202.467416           0.909091       0.00              0.00
# 2  2495.148862           1.000000     773.17            773.17
# 3  1666.670542           0.636364    1499.00           1499.00
# 4   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# 1                    0.000000                          0.000000
# 2                    1.000000                          0.000000
# 3                    0.083333                          0.000000
# 4                    0.083333                          0.000000
#
#    CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 0                0.000000                 0              2        1000.0
# 1                0.250000                 4              0        7000.0
# 2                0.000000                 0             12        7500.0
# 3                0.083333                 1              1        7500.0
# 4                0.000000                 0              1        1200.0
#
#       PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE
# 0   201.802084        139.509787          0.000000      12
# 1  4103.032597       1072.340217          0.222222      12
# 2   622.066742        627.284787          0.000000      12
# 3     0.000000               NaN          0.000000      12
# 4   678.334763        244.791237          0.000000      12

# %%
#
data.loc[(data['MINIMUM_PAYMENTS'].isnull()==True),'MINIMUM_PAYMENTS']=data['MINIMUM_PAYMENTS'].mean()
data.loc[(data['CREDIT_LIMIT'].isnull()==True),'CREDIT_LIMIT']=data['CREDIT_LIMIT'].mean()

# %% [markdown]
# ### Tạo phạm vi để phân khu giá trị. Bằng cách này, có thể giảm tác động lên tập dữ liệu mà không phải xóa các outliers

# %%
columns=['BALANCE', 'PURCHASES', 'ONEOFF_PURCHASES', 'INSTALLMENTS_PURCHASES', 'CASH_ADVANCE', 'CREDIT_LIMIT',
        'PAYMENTS', 'MINIMUM_PAYMENTS']

for c in columns:

    Range=c+'_RANGE'
    data[Range]=0
    data.loc[((data[c]>0)&(data[c]<=500)),Range]=1
    data.loc[((data[c]>500)&(data[c]<=1000)),Range]=2
    data.loc[((data[c]>1000)&(data[c]<=3000)),Range]=3
    data.loc[((data[c]>3000)&(data[c]<=5000)),Range]=4
    data.loc[((data[c]>5000)&(data[c]<=10000)),Range]=5
    data.loc[((data[c]>10000)),Range]=6

# %%
columns=['BALANCE_FREQUENCY', 'PURCHASES_FREQUENCY', 'ONEOFF_PURCHASES_FREQUENCY', 'PURCHASES_INSTALLMENTS_FREQUENCY',
         'CASH_ADVANCE_FREQUENCY', 'PRC_FULL_PAYMENT']

for c in columns:

    Range=c+'_RANGE'
    data[Range]=0
    data.loc[((data[c]>0)&(data[c]<=0.1)),Range]=1
    data.loc[((df[c]>0.1)&(data[c]<=0.2)),Range]=2
    data.loc[((df[c]>0.2)&(data[c]<=0.3)),Range]=3
    data.loc[((df[c]>0.3)&(data[c]<=0.4)),Range]=4
    data.loc[((df[c]>0.4)&(data[c]<=0.5)),Range]=5
    data.loc[((df[c]>0.5)&(data[c]<=0.6)),Range]=6
    data.loc[((df[c]>0.6)&(data[c]<=0.7)),Range]=7
    data.loc[((df[c]>0.7)&(data[c]<=0.8)),Range]=8
    data.loc[((df[c]>0.8)&(data[c]<=0.9)),Range]=9
    data.loc[((df[c]>0.9)&(data[c]<=1.0)),Range]=10

# %%
columns=['PURCHASES_TRX', 'CASH_ADVANCE_TRX']

for c in columns:

    Range=c+'_RANGE'
    data[Range]=0
    data.loc[((data[c]>0)&(data[c]<=5)),Range]=1
    data.loc[((data[c]>5)&(data[c]<=10)),Range]=2
    data.loc[((data[c]>10)&(data[c]<=15)),Range]=3
    data.loc[((data[c]>15)&(data[c]<=20)),Range]=4
    data.loc[((data[c]>20)&(data[c]<=30)),Range]=5
    data.loc[((data[c]>30)&(data[c]<=50)),Range]=6
    data.loc[((data[c]>50)&(data[c]<=100)),Range]=7
    data.loc[((data[c]>100)),Range]=8

# %%
data.drop(['BALANCE', 'BALANCE_FREQUENCY', 'PURCHASES',
       'ONEOFF_PURCHASES', 'INSTALLMENTS_PURCHASES', 'CASH_ADVANCE',
       'PURCHASES_FREQUENCY',  'ONEOFF_PURCHASES_FREQUENCY',
       'PURCHASES_INSTALLMENTS_FREQUENCY', 'CASH_ADVANCE_FREQUENCY',
       'CASH_ADVANCE_TRX', 'PURCHASES_TRX', 'CREDIT_LIMIT', 'PAYMENTS',
       'MINIMUM_PAYMENTS', 'PRC_FULL_PAYMENT' ], axis=1, inplace=True)

X= np.asarray(data)

# %% [markdown]
# ### Normalizing Inputs

# %%
scale = StandardScaler()
original_X = scale.fit_transform(X)
original_X.shape
# Out:
# (8950, 17)

# %% [markdown]
# > ## **Xây dựng mô hình**

# %% [markdown]
# ### Chọn số lượng cụm: Sử dụng phương pháp Elbow

# %% [markdown]
# #### Sơ lược về phương pháp Elbow:

# %% [markdown]
# Là một phương pháp được sử dụng để chọn số lượng cụm tối ưu trong thuật toán KMeans dựa trên sự thay đổi trong phương sai giữa các cụm.
#
# Cụ thể, phương pháp là:
# + **Trực quan hóa kết quả lên biểu đồ:** Trực quan hóa kết quả bằng cách vẽ biểu đồ của phương sai theo số lượng cụm. Phương sai thường giảm khi số lượng cụm tăng vì càng nhiều cụm thì sự tập trung của các điểm dữ liệu vào các cụm sẽ tăng lên.
#
# + **Chọn số lượng cụm tối ưu:** Xác định điểm "elbow" trên biểu đồ, nơi mà sự giảm đáng kể của phương sai bắt đầu giảm dần. Điểm này thường được xem là số lượng cụm tối ưu. Cụ thể, nếu trên biểu đồ có một điểm tương đối rõ ràng nơi phương sai bắt đầu giảm chậm hơn so với các giá trị trước đó, thì đó có thể được coi là điểm "elbow".

# %%
n_clusters=15
cost=[]
for i in range(1,n_clusters):
    kmean= KMeans(i)
    kmean.fit(original_X)
    cost.append(kmean.inertia_)

# %%
plt.plot(range(1,15),cost, 'rx-')
plt.xticks([i for i in range(1,15)])
plt.show()

# %% [markdown]
# Ta thấy điểm elbow tại 3, 4 hoặc 5. Chúng ta sẽ sử dụng độ đo  Silhouette Coefficient để xác định số cụm tốt hơn.

# %% [markdown]
# ### Chọn số lượng cụm: Sử dụng độ đo Silhouette

# %% [markdown]
# Độ đo Silhouette coefficient (SC) cho biết mức độ phù hợp của mỗi điểm dữ liệu với cụm mà nó được phân chia. Giá trị SC càng cao, nghĩa là điểm dữ liệu càng phù hợp với cụm của nó.

# %%
silhouette_scores = []

for n_cluster in range(2, 10):
    silhouette_scores.append(
        silhouette_score(original_X, KMeans(n_clusters = n_cluster).fit_predict(original_X)))

# Plotting a bar graph to compare the results
k = [i for i in range(2,10)]
plt.bar(k, silhouette_scores)
plt.xlabel('Number of clusters', fontsize = 10)
plt.ylabel('Silhouette Score', fontsize = 10)
plt.show()

# %% [markdown]
# Ta thấy số cụm có điểm số Silhouette cao nhất lần lượt là 2 và 3, thấp nhất tại 4. Do đó ta có thể thử số cụm là 2 hoặc 3.
# > Ta sẽ đánh giá độ hiệu quả của việc phân cụm với 2 và 3 cụm ở phần cuối.

# %% [markdown]
# ### Sinh thêm dữ liệu đầu vào

# %%
num_new_samples = 91050
# num_new_samples = 11050


new_data = np.empty((num_new_samples, original_X.shape[1]))
for col_idx in range(original_X.shape[1]):
  new_data[:,col_idx] = np.random.choice(original_X[:, col_idx], size=num_new_samples, replace=True)

X = np.concatenate((original_X, new_data), axis=0)

X.shape
# Out:
# (100000, 17)

# %%
np.savetxt('X.gz', X, fmt='%f')

# %% [markdown]
# ### Phiên bản Sckit-Learn: Dùng phương pháp KMeans của thư viện sklearn.cluster

# %% [markdown]
# #### Thiết kế

# %% [markdown]
# Ở phiên bản này chúng ta sử dụng thư viện nên có thể bỏ qua bước thiết kế.
# > Để có thể dễ dàng so sánh kết quả với các phiên bản sau, ta sẽ sử dụng các trung tâm ban đầu giống nhau là 6 điểm dữ liệu đầu tiên.

# %% [markdown]
# #### Cài đặt:

# %%
k = 20
kmean= KMeans(n_clusters=k, tol=0, init=X[:k])

start = time.time()
kmean.fit(X)
end = time.time()

correct_labels = kmean.labels_

# %% [markdown]
# #### Đánh giá

# %% [markdown]
# **To do**

# %% [markdown]
# ##### Thời gian chạy

# %%
kmean.n_iter_
# Out:
# 79

# %%
km_time = end - start
all_results.loc['use library', 'time (s)'] = km_time
all_results
# Out:
#              time (s)
# use library  0.622627

# %% [markdown]
# Với việc sử dụng Kmeans của thư viện sklearn, thuật toán thực thi rất nhanh chóng.

# %% [markdown]
# ##### Tính đúng đắn

# %% [markdown]
# Vì sử dụng K-Means của thư viện `sklearn`, nên khả năng sai là rất thấp.

# %% [markdown]
# ### Phiên bản tuần tự: Cài đặt hàm KMeans truyền thống

# %% [markdown]
# #### Thiết kế

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Dựa trên sơ đồ khối trên ta sẽ xây dựng ```class K_Means``` gồm các hàm sau:
# + `def init_center(self, X)`: thực hiện khởi tạo các trung tâm đầu tiên, ở bài này ta sẽ chọn k điểm đầu tiên dữ liệu.
# + `def assign_labels(self, X)`: phân cụm cho tất cả điểm dữ liệu. Trong đó gọi hàm:
#   + `def choose_label(self, x)`: với mỗi điểm dữ liệu tính khoảng cách từ nó đến các trung tâm và xác định cụm gần nhất. Với hàm tính khoảng cách:
#     + `def cal_distance(self, x, c)`: tính khoảng Euclid giữa một điểm dữ liệu và trung tâm.
# + `def cal_new_center(self)`: xác định các trung tâm mới sau khi các điểm dự liệu được phân lại cum.
# + `def fit(self, X)`: thực hiện vòng lặp gọi các hàm ở trên đến khi không có sự thay đổi các trung tâm.

# %% [markdown]
# #### Cài đặt

# %%
class K_Means:
  # init parameter of class
  def __init__(self, k):
    self.k = k
    self.centers = []
    self.labels = []
    self.num_loop = 0

  # chooose random k of center from X
  def init_center(self, X):
    # return X[np.random.choice(X.shape[0], self.k, replace=False)]
    return X[:self.k]

  # assign label for each point
  def assign_labels(self, X):
    return [self.choose_label(x) for x in X]

  # label of point
  def choose_label(self, x):
    return np.argmin([self.cal_distance(x, c) for c in self.centers])

  #  calculate distance between point and center
  def cal_distance(self, x, c):
    return ((x - c)**2).sum()

  # calculate new center
  def cal_new_center(self, X):
    indices=[]
    for i in range(self.k):
        cluster=[]
        for idx, l in enumerate(self.labels):
            if l==i: cluster.append(idx)
        indices.append(cluster)
    cluster_X = [X[i] for i in indices]

    # calculate the new centers
    new_centers = np.asarray([c.sum(axis=0)/len(c) for c in cluster_X])
    # new_centers = [c.sum(axis=0)/len(c) for c in cluster_X]
    # new_centers = [arr.tolist() for arr in new_centers]
    return new_centers

  def fit(self, X):
    self.centers = self.init_center(X);

    self.assign_time = self.cal_ncenter_time = self.check_time = 0
    while(1):
      self.num_loop += 1
      start_assign = time.time()
      self.labels = self.assign_labels(X)

      start_cal_ncenter = time.time()
      new_centers = self.cal_new_center(X)

      start_check = time.time()
      if np.all(new_centers == self.centers):
        break
      else:
        self.centers = new_centers

      end_loop = time.time()

      self.assign_time += (start_cal_ncenter - start_assign)
      self.cal_ncenter_time += (start_check - start_cal_ncenter)
      self.check_time += (end_loop - start_check)
    return self

# %%
km = K_Means(k = 20)
res = km.fit(X)

# %% [markdown]
# #### Đánh giá

# %% [markdown]
# ##### Thời gian chạy

# %%
total_time = res.assign_time + res.cal_ncenter_time + res.check_time
print("Thời gian phân cụm: ", res.assign_time)
print("Thời gian tính các trung tâm mới: ", res.cal_ncenter_time)
print("Thời gian kiểm tra sự thay đổi các trung tâm: ", res.check_time)
print("Tổng thời gian: ", total_time)
all_results.loc['sequential', 'time (s)'] = total_time
all_results
# Out:
# Thời gian phân cụm:  801.9689583778381
# Thời gian tính các trung tâm mới:  17.5545756816864
# Thời gian kiểm tra sự thay đổi các trung tâm:  0.0030684471130371094
# Tổng thời gian:  819.5266025066376
#                time (s)
# use library    0.622627
# sequential   819.526603

# %% [markdown]
# Phiên bản tuần tự của K-Means chạy chậm hơn rất nhiều so với thư viện sklearn.
# > Ta thấy phiên bản tuần tự tốn chủ yếu thời gian cho việc phân cụm các điểm dữ liệu sau khi các trung tâm mới được tính. Ta có thể thực hiện song song hóa phần này để tăng hiệu suất.

# %% [markdown]
# ##### Tính đúng đắn

# %% [markdown]
# Để kiểm tra tính đúng đắn, ta sẽ so sánh kết quả gán nhãn của phiên bản tuần tự và phiên bản sử dụng thư viện:

# %%
np.sum(res.labels == correct_labels)
# Out:
# 100000

# %% [markdown]
# Kết quả gán nhãn cho các điểm dữ liệu ở hai phiên bản tuần tự và sử dụng thư viện là giống nhau cho tất các điểm dữ liệu.
# > Vậy có thể kết luận thuật toán tuần tự K-Means ở trên là đúng.

# %% [markdown]
# ### Phiên bản song song cơ bản 1

# %% [markdown]
# #### Phân tích

# %% [markdown]
# Như đã thấy ở phiên bản tuần tự thì thời gian chủ yếu của thuật toán Kmeans là cho việc phân cụm dữ liệu. Cho nên ở phiên bản đầu tiên chúng ta sẽ tập trung song song cho việc phân cụm dữ liệu.

# %% [markdown]
# #### Thiết kế

# %% [markdown]
# Ta sẽ viết lại hàm `assign_label` với hàm này chính là kernel.
# - Input: X(các điểm dữ liệu đầu vào), centers(các trung tâm), k(số cụm), dis_arr(ma trận khoảng cách với mỗi dòng là 1 điểm dữ liệu và các trung tâm)
# - Các bước thực hiện:
#   +  Thực hiện cấp phát bộ nhớ cho `dis_arr`
#   + Gọi hàm kernel `assign_labels1[grid_size, block_size](X, self.centers, self.labels, self.k, dis_arr)`:
#     - Sử dụng block 1D với mỗi thread thực hiện xác định label cho 1 điểm  dữ liệu.
#     - Mỗi thread sẽ thực hiện tính khoảng cách từ một điểm dữ liệu đến các trung tâm.
#     - Sau đó mỗi thread sẽ thực hiện tìm index của khoảng cách nhỏ nhất có trong mảng `dis_arr[r,:]` để xác định label cho điểm dữ liệu được tính.
# - Output: mảng `labels` xác định nhãn cho các điểm dữ liệu.

# %% [markdown]
# #### Cài đặt

# %%
# assign label for each point
@cuda.jit
def assign_labels1(X, centers, labels, k, dis_arr):
  index = cuda.grid(1)
  dim = X.shape[1]

  if index < X.shape[0]:
    for idx_k in prange(k):
      dis = 0
      for i in range(dim):
        dis += (X[index, i] - centers[idx_k, i])**2
      dis_arr[index][idx_k] = dis

    idx_min = 0
    for i in range(1, k):
      if dis_arr[index, i] < dis_arr[index, idx_min]:
        idx_min = i

    labels[index] = idx_min

# %%
class K_Means_P:
  # init parameter of class
  def __init__(self, k):
    self.k = k
    self.num_loop = 0

  # chooose random k of center from X
  def init_center(self, X):
    return X[:self.k]


  def cal_new_center(self, X):
    indices=[]
    new_labels = self.labels.tolist()
    for i in range(self.k):
        cluster=[]
        for idx, l in enumerate(new_labels):
            if l==i: cluster.append(idx)
        indices.append(cluster)
    cluster_X = [X[i] for i in indices]

    # calculate the new centers
    new_centers = np.asarray([c.sum(axis=0)/len(c) for c in cluster_X])

    return new_centers

  def fit(self, X):
    # khởi tạo các mảng numpy cần thiết
    start_init = time.time()
    X = np.ascontiguousarray(X)
    self.centers = self.init_center(X);
    self.labels = np.zeros(len(X), dtype=int)
    dis_arr = np.zeros((X.shape[0], k), dtype=float)

    block_size = (32,)
    grid_size = (math.ceil(len(X) / block_size[0]),)

    # Khởi tạo các mốc thời gian
    self.assign_time = self.cal_ncenter_time = self.check_time = 0
    end_init = time.time()
    self.init_time = end_init - start_init

    while(1):
      self.num_loop += 1
      start_assign = time.time()

      # call kernel
      assign_labels1[grid_size, block_size](X, self.centers, self.labels, self.k, dis_arr)
      cuda.synchronize()

      start_cal_ncenter = time.time()
      new_centers = self.cal_new_center(X)

      start_check = time.time()
      if np.all(new_centers == self.centers):
        break
      else:
        self.centers = new_centers

      end_loop = time.time()

      self.assign_time += (start_cal_ncenter - start_assign)
      self.cal_ncenter_time += (start_check - start_cal_ncenter)
      self.check_time += (end_loop - start_check)
    return self

# %%
# small data to compile
x_test = np.random.rand(10,2)
km_test= K_Means_P(k=10)
res_test = km_test.fit(x_test)

# %%
km = K_Means_P(k = 20)
res_p = km.fit(X)

# %% [markdown]
# #### Đánh giá

# %% [markdown]
# ##### Thời gian chạy

# %%
total_time = res_p.assign_time + res_p.cal_ncenter_time + res_p.check_time + res_p.init_time
print("Thời gian khởi tạo: ", res_p.init_time)
print("Thời gian phân cụm: ", res_p.assign_time)
print("Thời gian tính các trung tâm mới: ", res_p.cal_ncenter_time)
print("Thời gian kiểm tra sự thay đổi các trung tâm: ", res_p.check_time)
print("Tổng thời gian: ", total_time)

all_results.loc['parallel basic', 'time (s)'] = total_time
all_results
# Out:
# Thời gian khởi tạo:  0.0001423358917236328
# Thời gian phân cụm:  1.4954516887664795
# Thời gian tính các trung tâm mới:  12.663727760314941
# Thời gian kiểm tra sự thay đổi các trung tâm:  0.003008604049682617
# Tổng thời gian:  14.162330389022827
#                   time (s)
# use library       0.622627
# sequential      819.526603
# parallel basic   14.162330

# %% [markdown]
# **Nhận xét:**
# - Thời gian thực thi của phiên bản song song cơ bản 1 đã giảm rất nhiều so với phiên bản tuần tự. Tuy nhiên vẫn chậm hơn sử dụng thư viện khoảng 20 lần.
# - Ta nhận thấy lúc này thời gian cho nhiệm vụ tính lại trung tâm mới chiếm phần lớn thời gian chạy thuật toán.

# %% [markdown]
# ##### Tính đúng đắn

# %% [markdown]
# Để kiểm tra tính đúng đắn, ta sẽ so sánh kết quả gán nhãn của phiên bản này và phiên bản sử dụng thư viện:

# %%
np.sum(res_p.labels == correct_labels)
# Out:
# 100000

# %% [markdown]
# Kết quả gán nhãn cho các điểm dữ liệu ở hai phiên bản song song cơ bản 1 và sử dụng thư viện là giống nhau cho tất các điểm dữ liệu.
# > Vậy có thể kết luận thuật toán song song cơ bản 1 cho K-Means ở trên là đúng.

# %% [markdown]
# ### Phiên bản song song cơ bản 1 + Tối ưu tính trung tâm trên CPU

# %% [markdown]
# #### Phân tích

# %% [markdown]
# Qua phiên bản song song cơ bản 1, ta thấy lúc này thời gian thực thi cho nhiệm vụ tính các trung tâm mới chiếm nhiều thời gian nhất trong các bước. Ta sẽ thực hiện tối ưu phần này.
#
# ---
#
# Trong các phiên bản trên, việc tính lại các các trung tâm mới bao gồm bước xác định index của các điểm dữ liệu trong từng cụm như sau:
# ```
#     for i in range(self.k):
#         cluster=[]
#         for idx, l in enumerate(new_labels):
#             if l==i: cluster.append(idx)
# ```
# Đoạn code này sẽ thực hiện duyệt qua từng cụm và ở mỗi cụm sẽ duyệt qua từng label của các điểm dữ liệu, nếu nó thuộc vào cụm thì index của nó sẽ được thêm vào mảng `cluster`.
#
# Ta thấy ở đây ta chỉ có thể song song phần duyệt qua từng cụm vì nó độc lập với nhau. Tuy nhiên số lượng cụm thường sẽ không quá lớn và kích thước `cluster` là chưa xác định được trước để cấp phát.
# -> Do đó ta sẽ không song song hàm tính lại các trung tâm mới mà sẽ viết một hàm mới tuần tự nhưng có thể tăng tốc cho phần này.

# %% [markdown]
# #### Thiết kế

# %% [markdown]
# - Chuyển mảng `labels` thành ma trận one-hot với kích thước (n, k). Mỗi dòng sẽ thể hiện label cho một điểm dữ liệu.
# - Nhân hai ma trận `labels.T`(k, n)  và `X`(n, dim). Ta được ma trận kết quả có kích thước (k, dim) với mỗi dòng là tổng của các điểm dữ liệu thuộc cùng một cụm.
# - Chia ma trận trên cho số điểm dữ liệu thuộc mỗi cụm, ta được kết quả là các trung tâm mới.

# %% [markdown]
# #### Cài đặt

# %%
class K_Means_PCPU:
  # init parameter of class
  def __init__(self, k):
    self.k = k
    self.num_loop = 0

  # chooose random k of center from X
  def init_center(self, X):
    return X[:self.k]

  def cal_new_center(self, X):
    # Tạo ma trận nhãn one-hot
    one_hot_labels = np.eye(self.k)[self.labels]

    # Tính toán tổng theo cụm
    cluster_sums = np.dot(one_hot_labels.T, X)

    # Đếm số điểm trong mỗi cụm
    cluster_counts = np.sum(one_hot_labels, axis=0)

    # Tránh chia cho 0
    cluster_counts[cluster_counts == 0] = 1

    # Tính trung tâm mới của các cụm
    new_centers = cluster_sums / cluster_counts[:, None]

    return new_centers

  def fit(self, X):
    # khởi tạo các mảng numpy cần thiết
    start_init = time.time()
    X = np.ascontiguousarray(X)
    self.centers = self.init_center(X);
    self.labels = np.zeros(len(X), dtype=int)
    dis_arr = np.zeros((X.shape[0], k), dtype=float)

    block_size = (32,)
    grid_size = (math.ceil(len(X) / block_size[0]),)

    # Khởi tạo các mốc thời gian
    self.assign_time = self.cal_ncenter_time = self.check_time = 0
    end_init = time.time()
    self.init_time = end_init - start_init

    while(1):
    # for i in range(2):
      self.num_loop += 1
      start_assign = time.time()

      # call kernel
      assign_labels1[grid_size, block_size](X, self.centers, self.labels, self.k, dis_arr)
      cuda.synchronize()

      start_cal_ncenter = time.time()
      new_centers = self.cal_new_center(X)

      start_check = time.time()
      if np.all(new_centers == self.centers):
        break
        # print("ok")
      else:
        self.centers = new_centers

      end_loop = time.time()

      self.assign_time += (start_cal_ncenter - start_assign)
      self.cal_ncenter_time += (start_check - start_cal_ncenter)
      self.check_time += (end_loop - start_check)
    return self

# %%
# small data to compile
x_test = np.random.rand(10,2)
km_test= K_Means_PCPU(k=10)
res_test = km_test.fit(x_test)

# %%
km = K_Means_PCPU(k = 20)
res_pcpu = km.fit(X)

# %% [markdown]
# #### Đánh giá

# %% [markdown]
# ##### Thời gian chạy

# %%
total_time = res_pcpu.assign_time + res_pcpu.cal_ncenter_time + res_pcpu.check_time + res_pcpu.init_time
print("Thời gian khởi tạo: ", res_pcpu.init_time)
print("Thời gian phân cụm: ", res_pcpu.assign_time)
print("Thời gian tính các trung tâm mới: ", res_pcpu.cal_ncenter_time)
print("Thời gian kiểm tra sự thay đổi các trung tâm: ", res_pcpu.check_time)
print("Tổng thời gian: ", total_time)

all_results.loc['parallel basic + opt cal center', 'time (s)'] = total_time
all_results
# Out:
# Thời gian khởi tạo:  0.0020351409912109375
# Thời gian phân cụm:  1.654658317565918
# Thời gian tính các trung tâm mới:  1.2130866050720215
# Thời gian kiểm tra sự thay đổi các trung tâm:  0.001986980438232422
# Tổng thời gian:  2.871767044067383
#                                    time (s)
# use library                        0.622627
# sequential                       819.526603
# parallel basic                    14.162330
# parallel basic + opt cal center    2.871767

# %% [markdown]
# **Nhận xét:**
# - Thời gian thực thi của phiên bản trên đã giảm khoảng 4 lần so với phiên bản song song cơ bản 1. Tuy nhiên vẫn chậm hơn phiên bản sử dụng thư viện.
# - Lúc này việc phân cụm lại chiếm nhiều thời gian nhất của thuật toán.

# %% [markdown]
# ##### Tính đúng đắn

# %% [markdown]
# Để kiểm tra tính đúng đắn, ta sẽ so sánh kết quả gán nhãn của phiên bản này và phiên bản sử dụng thư viện:

# %%
np.sum(res_pcpu.labels == correct_labels)
# Out:
# 100000

# %% [markdown]
# Kết quả gán nhãn cho các điểm dữ liệu ở hai phiên bản song song cở bản 1 kết hợp tối ưu tính toán trung tâm cụm và sử dụng thư viện là giống nhau cho tất các điểm dữ liệu.
# > Vậy có thể kết luận phiên bản K-Means ở trên là đúng.

# %% [markdown]
# ### Phiên bản song song cơ bản 2: Mỗi thread xử lý cho một chiều của dữ liệu

# %% [markdown]
# #### Phân tích

# %% [markdown]
# Ở phiên bản song song cơ bản 1 ta đang sử dụng 1 thread để tính toán cho một điểm dữ liệu. Do đó khi một điểm dữ liệu có số chiều lớn thì thread sẽ phải thực hiện nhiều phép toán.
#
# -> Ta có thể sử dụng block 2D với chiều x đại diện cho số chiều của một điểm dữ liệu và y đại diện cho số điểm dữ liệu để giảm khối lượng tính toán cho mỗi thread.

# %% [markdown]
# #### Thiết kế

# %% [markdown]
# Tương tự với phiên bản song song cơ bản 1 ta sẽ viết lại hàm `assign_label` với hàm này chính là kernel.
# - Input: X(các điểm dữ liệu đầu vào), centers(các trung tâm), k(số cụm), dis_arr(ma trận khoảng cách với mỗi dòng là 1 điểm dữ liệu tới các trung tâm)
# - Các bước thực hiện:
#   +  Thực hiện cấp phát bộ nhớ cho `dis_arr`
#   + Gọi hàm kernel `assign_labels2[grid_size, block_size](X, self.centers, self.labels, self.k, dis_arr)`:
#     - Sử dụng block 2D với mỗi thread thực hiện `k` vòng lặp tính khoảng cách `dis` cho 1 chiều của điểm dữ liệu đến chiều tương ứng của trung tâm thứ `idx_k`. Sau đó thực hiện cộng `dis` vào biến `dis_arr[r, idx_k]` với `r` là dòng thread thuộc vào.
#     - Sau khi tất cả thread đã thực hiện tính khoảng cách đến các trung tâm. Một thread sẽ được chọn để xác định index của phần tử nhỏ nhất có trong mảng `dis_arr[r,:]` để xác định label cho điểm dữ liệu được tính.
# - Output: mảng `labels` xác định nhãn cho các điểm dữ liệu.

# %% [markdown]
# #### Cài đặt

# %%
# assign label for each point
@cuda.jit
def assign_labels2(X, centers, labels, k, dis_arr):
  # r = cuda.blockIdx.y * cuda.blockDim.y + cuda.threadIdx.y
  # c = cuda.blockIdx.x * cuda.blockDim.x + cuda.threadIdx.x
  c, r = cuda.grid(2)

  if c < X.shape[1] and r < X.shape[0]:
    for idx_k in prange(k):
      dis = (X[r, c] - centers[idx_k, c])**2
      cuda.atomic.add(dis_arr, (r, idx_k), dis)

    cuda.syncthreads()
    if c == 0:
      idx_min = 0
      for i in range(1, k):
        if dis_arr[r, i] < dis_arr[r, idx_min]:
          idx_min = i

      labels[r] = idx_min

# %%
class K_Means_P2:
  # init parameter of class
  def __init__(self, k):
    self.k = k
    self.num_loop = 0

  # chooose random k of center from X
  def init_center(self, X):
    return X[:self.k]

  def cal_new_center(self, X):
    # Tạo ma trận nhãn one-hot
    one_hot_labels = np.eye(self.k)[self.labels]
    # Tính toán tổng theo cụm
    cluster_sums = np.dot(one_hot_labels.T, X)
    # Đếm số điểm trong mỗi cụm
    cluster_counts = np.sum(one_hot_labels, axis=0)
    # Tránh chia cho 0
    cluster_counts[cluster_counts == 0] = 1
    # Tính trung tâm mới của các cụm
    new_centers = cluster_sums / cluster_counts[:, None]

    return new_centers

  def fit(self, X):
    # khởi tạo các mảng numpy cần thiết
    start_init = time.time()
    X = np.ascontiguousarray(X)
    self.centers = self.init_center(X);
    self.labels = np.zeros(len(X), dtype=int)
    # dis_arr = np.zeros((X.shape[0], k), dtype=float)

    block_size = (32,32)
    grid_size = (math.ceil(X.shape[1] / block_size[0]), math.ceil(X.shape[0] / block_size[1]) )
    # Khởi tạo các mốc thời gian
    self.assign_time = self.cal_ncenter_time = self.check_time = 0
    end_init = time.time()
    self.init_time = end_init - start_init

    while(1):
    # for i in range(2):
      self.num_loop += 1
      start_assign = time.time()

      dis_arr = np.zeros((X.shape[0], self.k), dtype=float)
      # call kernel
      assign_labels2[grid_size, block_size](X, self.centers, self.labels, self.k, dis_arr)
      # self.labels = np.argmin(dis_arr, axis=1)
      cuda.synchronize()

      # Tính lại trung tâm
      start_cal_ncenter = time.time()
      new_centers = self.cal_new_center(X)

      # so sánh centers mới và center cũ
      start_check = time.time()
      if np.all(new_centers == self.centers):
        break
        # print("ok")
      else:
        self.centers = new_centers

      end_loop = time.time()

      self.assign_time += (start_cal_ncenter - start_assign)
      self.cal_ncenter_time += (start_check - start_cal_ncenter)
      self.check_time += (end_loop - start_check)
    return self

# %%
# small data to compile
x_test = np.random.rand(10,2)
km_test= K_Means_P2(k=10)
res_test = km_test.fit(x_test)

# %%
km = K_Means_P2(k = 20)
res_p2 = km.fit(X)

# %% [markdown]
# #### Đánh giá

# %% [markdown]
# ##### Thời gian chạy

# %%
total_time = res_p2.assign_time + res_p2.cal_ncenter_time + res_p2.check_time + res_p2.init_time
print("Thời gian khởi tạo: ", res_p2.init_time)
print("Thời gian phân cụm: ", res_p2.assign_time)
print("Thời gian tính các trung tâm mới: ", res_p2.cal_ncenter_time)
print("Thời gian kiểm tra sự thay đổi các trung tâm: ", res_p2.check_time)
print("Tổng thời gian: ", total_time)

all_results.loc['parallel basic 2', 'time (s)'] = total_time
all_results
# Out:
# Thời gian khởi tạo:  0.00011181831359863281
# Thời gian phân cụm:  1.8360140323638916
# Thời gian tính các trung tâm mới:  1.2120580673217773
# Thời gian kiểm tra sự thay đổi các trung tâm:  0.0019156932830810547
# Tổng thời gian:  3.0500996112823486
#                                    time (s)
# use library                        0.622627
# sequential                       819.526603
# parallel basic                    14.162330
# parallel basic + opt cal center    2.871767
# parallel basic 2                   3.050100

# %% [markdown]
# **Nhận xét:**
# - So với phiên bản trước thời gian thực thi của phiên bản này đã chậm hơn.
# - Nguyên nhân có thể là vì hàm `cuda.atomic.add()` và `cuda.syncthreads()` đã làm cho các thread phải đợi nhau thực hiện xong.

# %% [markdown]
# ##### Tính đúng đắn

# %% [markdown]
# Để kiểm tra tính đúng đắn, ta sẽ so sánh kết quả gán nhãn của phiên bản này và phiên bản sử dụng thư viện:

# %%
np.sum(res_p2.labels == correct_labels)
# Out:
# 100000

# %% [markdown]
# Kết quả gán nhãn cho các điểm dữ liệu ở hai phiên bản song song cơ bản 2 và sử dụng thư viện là giống nhau cho tất các điểm dữ liệu.
# > Vậy có thể kết luận phiên bản K-Means ở trên là đúng.

# %% [markdown]
# ### Phiên bản tối ưu 1: Tối ưu lại quá trình chuyển đổi

# %% [markdown]
# #### Phân tích

# %%
# %%writefile parallel2.py
import time
import numpy as np
import math
from numba import cuda, prange, jit
import numba

@cuda.jit
def assign_labels1(X, centers, labels, k, dis_arr):
  index = cuda.grid(1)
  dim = X.shape[1]

  if index < X.shape[0]:
    for idx_k in prange(k):
      dis = 0
      for i in range(dim):
        dis += (X[index, i] - centers[idx_k, i])**2
      dis_arr[index][idx_k] = dis

    idx_min = 0
    for i in range(1, k):
      if dis_arr[index, i] < dis_arr[index, idx_min]:
        idx_min = i

    labels[index] = idx_min

class K_Means_PCPU:
  # init parameter of class
  def __init__(self, k):
    self.k = k
    self.num_loop = 0

  # chooose random k of center from X
  def init_center(self, X):
    return X[:self.k]

  def cal_new_center(self, X):
    # Tạo ma trận nhãn one-hot
    one_hot_labels = np.eye(self.k)[self.labels]

    # Tính toán tổng theo cụm
    cluster_sums = np.dot(one_hot_labels.T, X)

    # Đếm số điểm trong mỗi cụm
    cluster_counts = np.sum(one_hot_labels, axis=0)

    # Tránh chia cho 0
    cluster_counts[cluster_counts == 0] = 1

    # Tính trung tâm mới của các cụm
    new_centers = cluster_sums / cluster_counts[:, None]

    return new_centers

  def fit(self, X):
    # khởi tạo các mảng numpy cần thiết
    start_init = time.time()
    X = np.ascontiguousarray(X)
    self.centers = self.init_center(X);
    self.labels = np.zeros(len(X), dtype=int)
    dis_arr = np.zeros((X.shape[0], self.k), dtype=float)

    block_size = (32,)
    grid_size = (math.ceil(len(X) / block_size[0]),)

    # Khởi tạo các mốc thời gian
    self.assign_time = self.cal_ncenter_time = self.check_time = 0
    end_init = time.time()
    self.init_time = end_init - start_init

    while(1):
    # for i in range(2):
      self.num_loop += 1
      start_assign = time.time()

      # call kernel
      assign_labels1[grid_size, block_size](X, self.centers, self.labels, self.k, dis_arr)
      cuda.synchronize()

      start_cal_ncenter = time.time()
      new_centers = self.cal_new_center(X)

      start_check = time.time()
      if np.all(new_centers == self.centers):
        break
        # print("ok")
      else:
        self.centers = new_centers

      end_loop = time.time()

      self.assign_time += (start_cal_ncenter - start_assign)
      self.cal_ncenter_time += (start_check - start_cal_ncenter)
      self.check_time += (end_loop - start_check)
    return self


# small data to compile
x_test = np.random.rand(10,2)
km_test= K_Means_PCPU(k=10)
res_test = km_test.fit(x_test)

X = np.loadtxt('X.gz', dtype=float)
km = K_Means_PCPU(k = 20)
res_p2 = km.fit(X)
# Out:
# Writing parallel2.py

# %%
# !python parallel2.py
# Out:
# /usr/local/lib/python3.10/dist-packages/numba/cuda/dispatcher.py:536: NumbaPerformanceWarning: Grid size 1 will likely result in GPU under-utilization due to low occupancy.
#   warn(NumbaPerformanceWarning(msg))
# /usr/local/lib/python3.10/dist-packages/numba/cuda/cudadrv/devicearray.py:886: NumbaPerformanceWarning: Host array used in CUDA kernel will incur copy overhead to/from device.
#   warn(NumbaPerformanceWarning(msg))

# %%
# !nvprof --print-gpu-trace python parallel2.py
# Out:
# /usr/local/lib/python3.10/dist-packages/numba/cuda/dispatcher.py:536: NumbaPerformanceWarning: Grid size 1 will likely result in GPU under-utilization due to low occupancy.
#   warn(NumbaPerformanceWarning(msg))
# ==5239== NVPROF is profiling process 5239, command: python3 parallel2.py
# /usr/local/lib/python3.10/dist-packages/numba/cuda/cudadrv/devicearray.py:886: NumbaPerformanceWarning: Host array used in CUDA kernel will incur copy overhead to/from device.
#   warn(NumbaPerformanceWarning(msg))
# ==5239== Profiling application: python3 parallel2.py
# ==5239== Profiling result:
#    Start  Duration            Grid Size      Block Size     Regs*    SSMem*    DSMem*      Size  Throughput  SrcMemType  DstMemType           Device   Context    Stream  Name
# 920.24ms     992ns                    -               -         -         -         -      160B  153.82MB/s    Pageable      Device     Tesla T4 (0)         1         7  [CUDA memcpy HtoD]
# 920.79ms     704ns                    -               -         -         -         -      160B  216.74MB/s    Pageable      Device     Tesla T4 (0)         1         7  [CUDA memcpy HtoD]
# 921.25ms     640ns                    -               -         -         -         -       80B  119.21MB/s    Pageable      Device     Tesla T4 (0)         1         7  [CUDA memcpy HtoD]
# 921.76ms     704ns                    -               -         -         -         -      800B  1.0583GB/s    Pageable      Device     Tesla T4 (0)         1         7  [CUDA memcpy HtoD]
# 921.95ms  14.432us              (1 1 1)        (32 1 1)        57        0B        0B         -           -           -           -     Tesla T4 (0)         1         7  _ZN6cudapy8__main__14assign_labels1B2v1B94cw51cXTLSUwv1sCUt9Uw11Ew1dRRQPKzLTg4gaGKFsG2oMQGEYakJSQB1PQBk0Bynm21OiwU1a0UoLGhDpQE8oxrNQE_3dE5ArrayIdLi2E1C7mutable7alignedE5ArrayIdLi2E1C7mutable7alignedE5ArrayIxLi1E1C7mutable7alignedEx5ArrayIdLi2E1C7mutable7alignedE [91]
# 922.14ms  2.0160us                    -               -         -         -         -      160B  75.688MB/s      Device    Pageable     Tesla T4 (0)         1         7  [CUDA memcpy DtoH]
# 922.31ms  1.6000us                    -               -         -         -         -      160B  95.367MB/s      Device    Pageable     Tesla T4 (0)         1         7  [CUDA memcpy DtoH]
# 922.44ms  1.6960us                    -               -         -         -         -       80B  44.985MB/s      Device    Pageable     Tesla T4 (0)         1         7  [CUDA memcpy DtoH]
# 922.60ms  1.6640us                    -               -         -         -         -      800B  458.50MB/s      Device    Pageable     Tesla T4 (0)         1         7  [CUDA memcpy DtoH]
# 1.32050s  2.9153ms                    -               -         -         -         -  12.970MB  4.3447GB/s    Pageable      Device     Tesla T4 (0)         1         7  [CUDA memcpy HtoD]
# 1.32403s     863ns                    -               -         -         -         -  2.6563KB  2.9353GB/s    Pageable      Device     Tesla T4 (0)         1         7  [CUDA memcpy HtoD]
# 1.32487s  67.583us                    -               -         -         -         -  781.25KB  11.024GB/s    Pageable      Device     Tesla T4 (0)         1         7  [CUDA memcpy HtoD]
# 1.32611s  6.1865ms                    -               -         -         -         -  15.259MB  2.4087GB/s    Pageable      Device     Tesla T4 (0)         1         7  [CUDA memcpy HtoD]
# 1.33246s  2.8010ms           (3125 1 1)        (32 1 1)        57        0B        0B         -           -           -           -     Tesla T4 (0)         1         7  _ZN6cudapy8__main__14assign_labels1B2v1B94cw51cXTLSUwv1sCUt9Uw11Ew1dRRQPKzLTg4gaGKFsG2oMQGEYakJSQB1PQBk0Bynm21OiwU1a0UoLGhDpQE8oxrNQE_3dE5ArrayIdLi2E1C7mutable7alignedE5ArrayIdLi2E1C7mutable7alignedE5ArrayIxLi1E1C7mutable7alignedEx5ArrayIdLi2E1C7mutable7alignedE [133]
# 1.33526s  2.5487ms                    -               -         -         -         -  12.970MB  4.9696GB/s      Device    Pageable     Tesla T4 (0)         1         7  [CUDA memcpy DtoH]
# 1.33826s  2.1120us                    -               -         -         -         -  2.6563KB  1.1994GB/s      Device    Pageable     Tesla T4 (0)         1         7  [CUDA memcpy DtoH]
# 1.33840s  62.654us                    -               -         -         -         -  781.25KB  11.892GB/s      Device    Pageable     Tesla T4 (0)         1         7  [CUDA memcpy DtoH]
# 1.33877s  16.511ms                    -               -         -         -         -  15.259MB  924.16MB/s      Device    Pageable     Tesla T4 (0)         1         7  [CUDA memcpy DtoH]
# 1.39072s  2.7922ms                    -               -         -         -         -  12.970MB  4.5363GB/s    Pageable      Device     Tesla T4 (0)         1         7  [CUDA memcpy HtoD]
# 1.39400s     863ns                    -               -         -         -         -  2.6563KB  2.9353GB/s    Pageable      Device     Tesla T4 (0)         1         7  [CUDA memcpy HtoD]
# 1.39459s  67.263us                    -               -         -         -         -  781.25KB  11.077GB/s    Pageable      Device     Tesla T4 (0)         1         7  [CUDA memcpy HtoD]
# 1.39553s  3.3916ms                    -               -         -         -         -  15.259MB  4.3936GB/s    Pageable      Device     Tesla T4 (0)         1         7  [CUDA memcpy HtoD]
# 1.39901s  2.7842ms           (3125 1 1)        (32 1 1)        57        0B        0B         -           -           -           -     Tesla T4 (0)         1         7  _ZN6cudapy8__main__14assign_labels1B2v1B94cw51cXTLSUwv1sCUt9Uw11Ew1dRRQPKzLTg4gaGKFsG2oMQGEYakJSQB1PQBk0Bynm21OiwU1a0UoLGhDpQE8oxrNQE_3dE5ArrayIdLi2E1C7mutable7alignedE5ArrayIdLi2E1C7mutable7alignedE5ArrayIxLi1E1C7mutable7alignedEx5ArrayIdLi2E1C7mutable7alignedE [175]
# 1.40180s  6.9307ms                    -               -         -         -         -  12.970MB  1.8275GB/s      Device    Pageable     Tesla T4 (0)         1         7  [CUDA memcpy DtoH]
# 1.40920s  1.9520us                    -               -         -         -         -  2.6563KB  1.2977GB/s      Device    Pageable     Tesla T4 (0)         1         7  [CUDA memcpy DtoH]
# 1.40933s  62.655us                    -               -         -         -         -  781.25KB  11.891GB/s      Device    Pageable     Tesla T4 (0)         1         7  [CUDA memcpy DtoH]
# 1.40968s  11.115ms                    -               -         -         -         -  15.259MB  1.3406GB/s      Device    Pageable     Tesla T4 (0)         1         7  [CUDA memcpy DtoH]
# 1.47983s  9.7789ms                    -               -         -         -         -  12.970MB  1.2952GB/s    Pageable      Device     Tesla T4 (0)         1         7  [CUDA memcpy HtoD]
# 1.49023s  1.2800us                    -               -         -         -         -  2.6563KB  1.9791GB/s    Pageable      Device     Tesla T4 (0)         1         7  [CUDA memcpy HtoD]
# 1.49083s  67.230us                    -               -         -         -         -  781.25KB  11.082GB/s    Pageable      Device     Tesla T4 (0)         1         7  [CUDA memcpy HtoD]
# 1.49179s  3.3155ms                    -               -         -         -         -  15.259MB  4.4943GB/s    Pageable      Device     Tesla T4 (0)         1         7  [CUDA memcpy HtoD]
# 1.49519s  2.7945ms           (3125 1 1)        (32 1 1)        57        0B        0B         -           -           -           -     Tesla T4 (0)         1         7  _ZN6cudapy8__main__14assign_labels1B2v1B94cw51cXTLSUwv1sCUt9Uw11Ew1dRRQPKzLTg4gaGKFsG2oMQGEYakJSQB1PQBk0Bynm21OiwU1a0UoLGhDpQE8oxrNQE_3dE5ArrayIdLi2E1C7mutable7alignedE5ArrayIdLi2E1C7mutable7alignedE5ArrayIxLi1E1C7mutable7alignedEx5ArrayIdLi2E1C7mutable7alignedE [228]
# 1.49799s  6.8256ms                    -               -         -         -         -  12.970MB  1.8557GB/s      Device    Pageable     Tesla T4 (0)         1         7  [CUDA memcpy DtoH]
# 1.50537s  2.2400us                    -               -         -         -         -  2.6563KB  1.1309GB/s      Device    Pageable     Tesla T4 (0)         1         7  [CUDA memcpy DtoH]
# 1.50551s  62.654us                    -               -         -         -         -  781.25KB  11.892GB/s      Device    Pageable     Tesla T4 (0)         1         7  [CUDA memcpy DtoH]
# 1.50586s  10.232ms                    -               -         -         -         -  15.259MB  1.4564GB/s      Device    Pageable     Tesla T4 (0)         1         7  [CUDA memcpy DtoH]
# 1.54640s  2.8933ms                    -               -         -         -         -  12.970MB  4.3777GB/s    Pageable      Device     Tesla T4 (0)         1         7  [CUDA memcpy HtoD]
# 1.54980s     864ns                    -               -         -         -         -  2.6563KB  2.9319GB/s    Pageable      Device     Tesla T4 (0)         1         7  [CUDA memcpy HtoD]
# 1.55041s  67.230us                    -               -         -         -         -  781.25KB  11.082GB/s    Pageable      Device     Tesla T4 (0)         1         7  [CUDA memcpy HtoD]
# 1.55140s  3.5100ms                    -               -         -         -         -  15.259MB  4.2453GB/s    Pageable      Device     Tesla T4 (0)         1         7  [CUDA memcpy HtoD]
# 1.55500s  2.7891ms           (3125 1 1)        (32 1 1)        57        0B        0B         -           -           -           -     Tesla T4 (0)         1         7  _ZN6cudapy8__main__14assign_labels1B2v1B94cw51cXTLSUwv1sCUt9Uw11Ew1dRRQPKzLTg4gaGKFsG2oMQGEYakJSQB1PQBk0Bynm21OiwU1a0UoLGhDpQE8oxrNQE_3dE5ArrayIdLi2E1C7mutable7alignedE5ArrayIdLi2E1C7mutable7alignedE5ArrayIxLi1E1C7mutable7alignedEx5ArrayIdLi2E1C7mutable7alignedE [270]
# 1.55780s  2.0755ms                    -               -         -         -         -  12.970MB  6.1026GB/s      Device    Pageable     Tesla T4 (0)         1         7  [CUDA memcpy DtoH]
# 1.56035s  1.9200us                    -               -         -         -         -  2.6563KB  1.3194GB/s      Device    Pageable     Tesla T4 (0)         1         7  [CUDA memcpy DtoH]
# 1.56049s  62.719us                    -               -         -         -         -  781.25KB  11.879GB/s      Device    Pageable     Tesla T4 (0)         1         7  [CUDA memcpy DtoH]
# 1.56088s  3.2310ms                    -               -         -         -         -  15.259MB  4.6119GB/s      Device    Pageable     Tesla T4 (0)         1         7  [CUDA memcpy DtoH]
# 1.59100s  2.8147ms                    -               -         -         -         -  12.970MB  4.4999GB/s    Pageable      Device     Tesla T4 (0)         1         7  [CUDA memcpy HtoD]
# 1.59427s     895ns                    -               -         -         -         -  2.6563KB  2.8304GB/s    Pageable      Device     Tesla T4 (0)         1         7  [CUDA memcpy HtoD]
# 1.59505s  67.102us                    -               -         -         -         -  781.25KB  11.103GB/s    Pageable      Device     Tesla T4 (0)         1         7  [CUDA memcpy HtoD]
# 1.59602s  3.4359ms                    -               -         -         -         -  15.259MB  4.3369GB/s    Pageable      Device     Tesla T4 (0)         1         7  [CUDA memcpy HtoD]
# 1.59955s  2.7746ms           (3125 1 1)        (32 1 1)        57        0B        0B         -           -           -           -     Tesla T4 (0)         1         7  _ZN6cudapy8__main__14assign_labels1B2v1B94cw51cXTLSUwv1sCUt9Uw11Ew1dRRQPKzLTg4gaGKFsG2oMQGEYakJSQB1PQBk0Bynm21OiwU1a0UoLGhDpQE8oxrNQE_3dE5ArrayIdLi2E1C7mutable7alignedE5ArrayIdLi2E1C7mutable7alignedE5ArrayIxLi1E1C7mutable7alignedEx5ArrayIdLi2E1C7mutable7alignedE [312]
# 1.60233s  1.9960ms                    -               -         -         -         -  12.970MB  6.3458GB/s      Device    Pageable     Tesla T4 (0)         1         7  [CUDA memcpy DtoH]
# 1.60479s  2.1760us                    -               -         -         -         -  2.6563KB  1.1642GB/s      Device    Pageable     Tesla T4 (0)         1         7  [CUDA memcpy DtoH]
# 1.60492s  62.591us                    -               -         -         -         -  781.25KB  11.904GB/s      Device    Pageable     Tesla T4 (0)         1         7  [CUDA memcpy DtoH]
# 1.60524s  3.2165ms                    -               -         -         -         -  15.259MB  4.6327GB/s      Device    Pageable     Tesla T4 (0)         1         7  [CUDA memcpy DtoH]
# 1.63809s  2.8346ms                    -               -         -         -         -  12.970MB  4.4684GB/s    Pageable      Device     Tesla T4 (0)         1         7  [CUDA memcpy HtoD]
# 1.64155s  1.3120us                    -               -         -         -         -  2.6563KB  1.9308GB/s    Pageable      Device     Tesla T4 (0)         1         7  [CUDA memcpy HtoD]
# 1.64215s  67.135us                    -               -         -         -         -  781.25KB  11.098GB/s    Pageable      Device     Tesla T4 (0)         1         7  [CUDA memcpy HtoD]
# 1.64307s  3.3939ms                    -               -         -         -         -  15.259MB  4.3906GB/s    Pageable      Device     Tesla T4 (0)         1         7  [CUDA memcpy HtoD]
# 1.64655s  2.7987ms           (3125 1 1)        (32 1 1)        57        0B        0B         -           -           -           -     Tesla T4 (0)         1         7  _ZN6cudapy8__main__14assign_labels1B2v1B94cw51cXTLSUwv1sCUt9Uw11Ew1dRRQPKzLTg4gaGKFsG2oMQGEYakJSQB1PQBk0Bynm21OiwU1a0UoLGhDpQE8oxrNQE_3dE5ArrayIdLi2E1C7mutable7alignedE5ArrayIdLi2E1C7mutable7alignedE5ArrayIxLi1E1C7mutable7alignedEx5ArrayIdLi2E1C7mutable7alignedE [365]
# 1.64935s  1.8823ms                    -               -         -         -         -  12.970MB  6.7290GB/s      Device    Pageable     Tesla T4 (0)         1         7  [CUDA memcpy DtoH]
# 1.65167s  1.9510us                    -               -         -         -         -  2.6563KB  1.2984GB/s      Device    Pageable     Tesla T4 (0)         1         7  [CUDA memcpy DtoH]
# 1.65563s  63.006us                    -               -         -         -         -  781.25KB  11.825GB/s      Device    Pageable     Tesla T4 (0)         1         7  [CUDA memcpy DtoH]
# 1.65599s  3.2500ms                    -               -         -         -         -  15.259MB  4.5850GB/s      Device    Pageable     Tesla T4 (0)         1         7  [CUDA memcpy DtoH]
# 1.67947s  2.8256ms                    -               -         -         -         -  12.970MB  4.4826GB/s    Pageable      Device     Tesla T4 (0)         1         7  [CUDA memcpy HtoD]
# 1.68276s     896ns                    -               -         -         -         -  2.6563KB  2.8272GB/s    Pageable      Device     Tesla T4 (0)         1         7  [CUDA memcpy HtoD]
# 1.68335s  67.102us                    -               -         -         -         -  781.25KB  11.103GB/s    Pageable      Device     Tesla T4 (0)         1         7  [CUDA memcpy HtoD]
# 1.68429s  3.5593ms                    -               -         -         -         -  15.259MB  4.1865GB/s    Pageable      Device     Tesla T4 (0)         1         7  [CUDA memcpy HtoD]
# 1.68794s  2.7924ms           (3125 1 1)        (32 1 1)        57        0B        0B         -           -           -           -     Tesla T4 (0)         1         7  _ZN6cudapy8__main__14assign_labels1B2v1B94cw51cXTLSUwv1sCUt9Uw11Ew1dRRQPKzLTg4gaGKFsG2oMQGEYakJSQB1PQBk0Bynm21OiwU1a0UoLGhDpQE8oxrNQE_3dE5ArrayIdLi2E1C7mutable7alignedE5ArrayIdLi2E1C7mutable7alignedE5ArrayIxLi1E1C7mutable7alignedEx5ArrayIdLi2E1C7mutable7alignedE [407]
# 1.69074s  1.9076ms                    -               -         -         -         -  12.970MB  6.6399GB/s      Device    Pageable     Tesla T4 (0)         1         7  [CUDA memcpy DtoH]
# 1.69308s  2.1760us                    -               -         -         -         -  2.6563KB  1.1642GB/s      Device    Pageable     Tesla T4 (0)         1         7  [CUDA memcpy DtoH]
# 1.69320s  62.719us                    -               -         -         -         -  781.25KB  11.879GB/s      Device    Pageable     Tesla T4 (0)         1         7  [CUDA memcpy DtoH]
# 1.69359s  3.1897ms                    -               -         -         -         -  15.259MB  4.6716GB/s      Device    Pageable     Tesla T4 (0)         1         7  [CUDA memcpy DtoH]
# 1.72251s  2.7663ms                    -               -         -         -         -  12.970MB  4.5787GB/s    Pageable      Device     Tesla T4 (0)         1         7  [CUDA memcpy HtoD]
# 1.72574s     896ns                    -               -         -         -         -  2.6563KB  2.8272GB/s    Pageable      Device     Tesla T4 (0)         1         7  [CUDA memcpy HtoD]
# 1.73082s  67.326us                    -               -         -         -         -  781.25KB  11.066GB/s    Pageable      Device     Tesla T4 (0)         1         7  [CUDA memcpy HtoD]
# 1.73180s  5.1098ms                    -               -         -         -         -  15.259MB  2.9162GB/s    Pageable      Device     Tesla T4 (0)         1         7  [CUDA memcpy HtoD]
# 1.73704s  2.8022ms           (3125 1 1)        (32 1 1)        57        0B        0B         -           -           -           -     Tesla T4 (0)         1         7  _ZN6cudapy8__main__14assign_labels1B2v1B94cw51cXTLSUwv1sCUt9Uw11Ew1dRRQPKzLTg4gaGKFsG2oMQGEYakJSQB1PQBk0Bynm21OiwU1a0UoLGhDpQE8oxrNQE_3dE5ArrayIdLi2E1C7mutable7alignedE5ArrayIdLi2E1C7mutable7alignedE5ArrayIxLi1E1C7mutable7alignedEx5ArrayIdLi2E1C7mutable7alignedE [449]
# 1.73985s  4.8747ms                    -               -         -         -         -  12.970MB  2.5983GB/s      Device    Pageable     Tesla T4 (0)         1         7  [CUDA memcpy DtoH]
# 1.74522s  1.9850us                    -               -         -         -         -  2.6563KB  1.2762GB/s      Device    Pageable     Tesla T4 (0)         1         7  [CUDA memcpy DtoH]
# 1.74535s  62.655us                    -               -         -         -         -  781.25KB  11.891GB/s      Device    Pageable     Tesla T4 (0)         1         7  [CUDA memcpy DtoH]
# 1.74569s  7.9747ms                    -               -         -         -         -  15.259MB  1.8685GB/s      Device    Pageable     Tesla T4 (0)         1         7  [CUDA memcpy DtoH]
# 1.79433s  2.8943ms                    -               -         -         -         -  12.970MB  4.3762GB/s    Pageable      Device     Tesla T4 (0)         1         7  [CUDA memcpy HtoD]
# 1.80226s     864ns                    -               -         -         -         -  2.6563KB  2.9319GB/s    Pageable      Device     Tesla T4 (0)         1         7  [CUDA memcpy HtoD]
# 1.80291s  67.550us                    -               -         -         -         -  781.25KB  11.030GB/s    Pageable      Device     Tesla T4 (0)         1         7  [CUDA memcpy HtoD]
# 1.80388s  8.0159ms                    -               -         -         -         -  15.259MB  1.8590GB/s    Pageable      Device     Tesla T4 (0)         1         7  [CUDA memcpy HtoD]
# 1.81199s  2.8172ms           (3125 1 1)        (32 1 1)        57        0B        0B         -           -           -           -     Tesla T4 (0)         1         7  _ZN6cudapy8__main__14assign_labels1B2v1B94cw51cXTLSUwv1sCUt9Uw11Ew1dRRQPKzLTg4gaGKFsG2oMQGEYakJSQB1PQBk0Bynm21OiwU1a0UoLGhDpQE8oxrNQE_3dE5ArrayIdLi2E1C7mutable7alignedE5ArrayIdLi2E1C7mutable7alignedE5ArrayIxLi1E1C7mutable7alignedEx5ArrayIdLi2E1C7mutable7alignedE [502]
# 1.81481s  3.7038ms                    -               -         -         -         -  12.970MB  3.4197GB/s      Device    Pageable     Tesla T4 (0)         1         7  [CUDA memcpy DtoH]
# 1.81907s  2.1760us                    -               -         -         -         -  2.6563KB  1.1642GB/s      Device    Pageable     Tesla T4 (0)         1         7  [CUDA memcpy DtoH]
# 1.81920s  62.655us                    -               -         -         -         -  781.25KB  11.891GB/s      Device    Pageable     Tesla T4 (0)         1         7  [CUDA memcpy DtoH]
# 1.81959s  7.6954ms                    -               -         -         -         -  15.259MB  1.9364GB/s      Device    Pageable     Tesla T4 (0)         1         7  [CUDA memcpy DtoH]
# 1.86594s  2.9148ms                    -               -         -         -         -  12.970MB  4.3454GB/s    Pageable      Device     Tesla T4 (0)         1         7  [CUDA memcpy HtoD]
# 1.86943s     896ns                    -               -         -         -         -  2.6563KB  2.8272GB/s    Pageable      Device     Tesla T4 (0)         1         7  [CUDA memcpy HtoD]
# 1.87008s  67.166us                    -               -         -         -         -  781.25KB  11.093GB/s    Pageable      Device     Tesla T4 (0)         1         7  [CUDA memcpy HtoD]
# 1.87588s  3.3795ms                    -               -         -         -         -  15.259MB  4.4093GB/s    Pageable      Device     Tesla T4 (0)         1         7  [CUDA memcpy HtoD]
# 1.87934s  2.7839ms           (3125 1 1)        (32 1 1)        57        0B        0B         -           -           -           -     Tesla T4 (0)         1         7  _ZN6cudapy8__main__14assign_labels1B2v1B94cw51cXTLSUwv1sCUt9Uw11Ew1dRRQPKzLTg4gaGKFsG2oMQGEYakJSQB1PQBk0Bynm21OiwU1a0UoLGhDpQE8oxrNQE_3dE5ArrayIdLi2E1C7mutable7alignedE5ArrayIdLi2E1C7mutable7alignedE5ArrayIxLi1E1C7mutable7alignedEx5ArrayIdLi2E1C7mutable7alignedE [544]
# 1.88376s  2.5023ms                    -               -         -         -         -  12.970MB  5.0617GB/s      Device    Pageable     Tesla T4 (0)         1         7  [CUDA memcpy DtoH]
# 1.88678s  2.0480us                    -               -         -         -         -  2.6563KB  1.2369GB/s      Device    Pageable     Tesla T4 (0)         1         7  [CUDA memcpy DtoH]
# 1.88692s  62.943us                    -               -         -         -         -  781.25KB  11.837GB/s      Device    Pageable     Tesla T4 (0)         1         7  [CUDA memcpy DtoH]
# 1.88731s  8.0955ms                    -               -         -         -         -  15.259MB  1.8407GB/s      Device    Pageable     Tesla T4 (0)         1         7  [CUDA memcpy DtoH]
# 1.93175s  10.127ms                    -               -         -         -         -  12.970MB  1.2508GB/s    Pageable      Device     Tesla T4 (0)         1         7  [CUDA memcpy HtoD]
# 1.94257s  1.3120us                    -               -         -         -         -  2.6563KB  1.9308GB/s    Pageable      Device     Tesla T4 (0)         1         7  [CUDA memcpy HtoD]
# 1.94321s  67.326us                    -               -         -         -         -  781.25KB  11.066GB/s    Pageable      Device     Tesla T4 (0)         1         7  [CUDA memcpy HtoD]
# 1.94823s  5.2493ms                    -               -         -         -         -  15.259MB  2.8387GB/s    Pageable      Device     Tesla T4 (0)         1         7  [CUDA memcpy HtoD]
# 1.95358s  2.7818ms           (3125 1 1)        (32 1 1)        57        0B        0B         -           -           -           -     Tesla T4 (0)         1         7  _ZN6cudapy8__main__14assign_labels1B2v1B94cw51cXTLSUwv1sCUt9Uw11Ew1dRRQPKzLTg4gaGKFsG2oMQGEYakJSQB1PQBk0Bynm21OiwU1a0UoLGhDpQE8oxrNQE_3dE5ArrayIdLi2E1C7mutable7alignedE5ArrayIdLi2E1C7mutable7alignedE5ArrayIxLi1E1C7mutable7alignedEx5ArrayIdLi2E1C7mutable7alignedE [597]
# 1.95637s  5.5844ms                    -               -         -         -         -  12.970MB  2.2681GB/s      Device    Pageable     Tesla T4 (0)         1         7  [CUDA memcpy DtoH]
# 1.96250s  2.2080us                    -               -         -         -         -  2.6563KB  1.1473GB/s      Device    Pageable     Tesla T4 (0)         1         7  [CUDA memcpy DtoH]
# 1.96263s  62.622us                    -               -         -         -         -  781.25KB  11.898GB/s      Device    Pageable     Tesla T4 (0)         1         7  [CUDA memcpy DtoH]
# 1.96301s  9.6247ms                    -               -         -         -         -  15.259MB  1.5482GB/s      Device    Pageable     Tesla T4 (0)         1         7  [CUDA memcpy DtoH]
# 2.00614s  2.9163ms                    -               -         -         -         -  12.970MB  4.3432GB/s    Pageable      Device     Tesla T4 (0)         1         7  [CUDA memcpy HtoD]
# 2.00954s     864ns                    -               -         -         -         -  2.6563KB  2.9319GB/s    Pageable      Device     Tesla T4 (0)         1         7  [CUDA memcpy HtoD]
# 2.01017s  67.198us                    -               -         -         -         -  781.25KB  11.088GB/s    Pageable      Device     Tesla T4 (0)         1         7  [CUDA memcpy HtoD]
# 2.01614s  7.5836ms                    -               -         -         -         -  15.259MB  1.9649GB/s    Pageable      Device     Tesla T4 (0)         1         7  [CUDA memcpy HtoD]
# 2.02383s  2.7647ms           (3125 1 1)        (32 1 1)        57        0B        0B         -           -           -           -     Tesla T4 (0)         1         7  _ZN6cudapy8__main__14assign_labels1B2v1B94cw51cXTLSUwv1sCUt9Uw11Ew1dRRQPKzLTg4gaGKFsG2oMQGEYakJSQB1PQBk0Bynm21OiwU1a0UoLGhDpQE8oxrNQE_3dE5ArrayIdLi2E1C7mutable7alignedE5ArrayIdLi2E1C7mutable7alignedE5ArrayIxLi1E1C7mutable7alignedEx5ArrayIdLi2E1C7mutable7alignedE [639]
# 2.02660s  7.3215ms                    -               -         -         -         -  12.970MB  1.7300GB/s      Device    Pageable     Tesla T4 (0)         1         7  [CUDA memcpy DtoH]
# 2.03444s  1.9200us                    -               -         -         -         -  2.6563KB  1.3194GB/s      Device    Pageable     Tesla T4 (0)         1         7  [CUDA memcpy DtoH]
# 2.03460s  62.879us                    -               -         -         -         -  781.25KB  11.849GB/s      Device    Pageable     Tesla T4 (0)         1         7  [CUDA memcpy DtoH]
# 2.03650s  3.4523ms                    -               -         -         -         -  15.259MB  4.3163GB/s      Device    Pageable     Tesla T4 (0)         1         7  [CUDA memcpy DtoH]
# 2.08237s  2.9231ms                    -               -         -         -         -  12.970MB  4.3331GB/s    Pageable      Device     Tesla T4 (0)         1         7  [CUDA memcpy HtoD]
# 2.08585s  1.3120us                    -               -         -         -         -  2.6563KB  1.9308GB/s    Pageable      Device     Tesla T4 (0)         1         7  [CUDA memcpy HtoD]
# 2.09163s  67.262us                    -               -         -         -         -  781.25KB  11.077GB/s    Pageable      Device     Tesla T4 (0)         1         7  [CUDA memcpy HtoD]
# 2.09267s  7.6373ms                    -               -         -         -         -  15.259MB  1.9511GB/s    Pageable      Device     Tesla T4 (0)         1         7  [CUDA memcpy HtoD]
# 2.10041s  2.7735ms           (3125 1 1)        (32 1 1)        57        0B        0B         -           -           -           -     Tesla T4 (0)         1         7  _ZN6cudapy8__main__14assign_labels1B2v1B94cw51cXTLSUwv1sCUt9Uw11Ew1dRRQPKzLTg4gaGKFsG2oMQGEYakJSQB1PQBk0Bynm21OiwU1a0UoLGhDpQE8oxrNQE_3dE5ArrayIdLi2E1C7mutable7alignedE5ArrayIdLi2E1C7mutable7alignedE5ArrayIxLi1E1C7mutable7alignedEx5ArrayIdLi2E1C7mutable7alignedE [681]
# 2.10319s  7.2224ms                    -               -         -         -         -  12.970MB  1.7537GB/s      Device    Pageable     Tesla T4 (0)         1         7  [CUDA memcpy DtoH]
# 2.11093s  2.1440us                    -               -         -         -         -  2.6563KB  1.1815GB/s      Device    Pageable     Tesla T4 (0)         1         7  [CUDA memcpy DtoH]
# 2.11106s  62.655us                    -               -         -         -         -  781.25KB  11.891GB/s      Device    Pageable     Tesla T4 (0)         1         7  [CUDA memcpy DtoH]
# 2.11143s  7.3940ms                    -               -         -         -         -  15.259MB  2.0153GB/s      Device    Pageable     Tesla T4 (0)         1         7  [CUDA memcpy DtoH]
# 2.15626s  2.8396ms                    -               -         -         -         -  12.970MB  4.4605GB/s    Pageable      Device     Tesla T4 (0)         1         7  [CUDA memcpy HtoD]
# 2.16459s  1.3120us                    -               -         -         -         -  2.6563KB  1.9308GB/s    Pageable      Device     Tesla T4 (0)         1         7  [CUDA memcpy HtoD]
# 2.16518s  67.454us                    -               -         -         -         -  781.25KB  11.045GB/s    Pageable      Device     Tesla T4 (0)         1         7  [CUDA memcpy HtoD]
# 2.16736s  7.9804ms                    -               -         -         -         -  15.259MB  1.8672GB/s    Pageable      Device     Tesla T4 (0)         1         7  [CUDA memcpy HtoD]
# 2.17543s  2.8174ms           (3125 1 1)        (32 1 1)        57        0B        0B         -           -           -           -     Tesla T4 (0)         1         7  _ZN6cudapy8__main__14assign_labels1B2v1B94cw51cXTLSUwv1sCUt9Uw11Ew1dRRQPKzLTg4gaGKFsG2oMQGEYakJSQB1PQBk0Bynm21OiwU1a0UoLGhDpQE8oxrNQE_3dE5ArrayIdLi2E1C7mutable7alignedE5ArrayIdLi2E1C7mutable7alignedE5ArrayIxLi1E1C7mutable7alignedEx5ArrayIdLi2E1C7mutable7alignedE [734]
# 2.17824s  6.6784ms                    -               -         -         -         -  12.970MB  1.8966GB/s      Device    Pageable     Tesla T4 (0)         1         7  [CUDA memcpy DtoH]
# 2.18705s  1.9520us                    -               -         -         -         -  2.6563KB  1.2977GB/s      Device    Pageable     Tesla T4 (0)         1         7  [CUDA memcpy DtoH]
# 2.18719s  63.006us                    -               -         -         -         -  781.25KB  11.825GB/s      Device    Pageable     Tesla T4 (0)         1         7  [CUDA memcpy DtoH]
# 2.18813s  3.2064ms                    -               -         -         -         -  15.259MB  4.6473GB/s      Device    Pageable     Tesla T4 (0)         1         7  [CUDA memcpy DtoH]
# 2.22622s  2.8326ms                    -               -         -         -         -  12.970MB  4.4715GB/s    Pageable      Device     Tesla T4 (0)         1         7  [CUDA memcpy HtoD]
# 2.23394s     864ns                    -               -         -         -         -  2.6563KB  2.9319GB/s    Pageable      Device     Tesla T4 (0)         1         7  [CUDA memcpy HtoD]
# 2.23459s  67.646us                    -               -         -         -         -  781.25KB  11.014GB/s    Pageable      Device     Tesla T4 (0)         1         7  [CUDA memcpy HtoD]
# 2.23681s  5.4130ms                    -               -         -         -         -  15.259MB  2.7529GB/s    Pageable      Device     Tesla T4 (0)         1         7  [CUDA memcpy HtoD]
# 2.24229s  2.7794ms           (3125 1 1)        (32 1 1)        57        0B        0B         -           -           -           -     Tesla T4 (0)         1         7  _ZN6cudapy8__main__14assign_labels1B2v1B94cw51cXTLSUwv1sCUt9Uw11Ew1dRRQPKzLTg4gaGKFsG2oMQGEYakJSQB1PQBk0Bynm21OiwU1a0UoLGhDpQE8oxrNQE_3dE5ArrayIdLi2E1C7mutable7alignedE5ArrayIdLi2E1C7mutable7alignedE5ArrayIxLi1E1C7mutable7alignedEx5ArrayIdLi2E1C7mutable7alignedE [776]
# 2.24508s  5.7596ms                    -               -         -         -         -  12.970MB  2.1991GB/s      Device    Pageable     Tesla T4 (0)         1         7  [CUDA memcpy DtoH]
# 2.25400s  2.2080us                    -               -         -         -         -  2.6563KB  1.1473GB/s      Device    Pageable     Tesla T4 (0)         1         7  [CUDA memcpy DtoH]
# 2.25415s  63.102us                    -               -         -         -         -  781.25KB  11.807GB/s      Device    Pageable     Tesla T4 (0)         1         7  [CUDA memcpy DtoH]
# 2.25511s  5.0911ms                    -               -         -         -         -  15.259MB  2.9269GB/s      Device    Pageable     Tesla T4 (0)         1         7  [CUDA memcpy DtoH]
# 2.29169s  7.9401ms                    -               -         -         -         -  12.970MB  1.5952GB/s    Pageable      Device     Tesla T4 (0)         1         7  [CUDA memcpy HtoD]
# 2.30017s     864ns                    -               -         -         -         -  2.6563KB  2.9319GB/s    Pageable      Device     Tesla T4 (0)         1         7  [CUDA memcpy HtoD]
# 2.30098s  67.135us                    -               -         -         -         -  781.25KB  11.098GB/s    Pageable      Device     Tesla T4 (0)         1         7  [CUDA memcpy HtoD]
# 2.30501s  4.4162ms                    -               -         -         -         -  15.259MB  3.3742GB/s    Pageable      Device     Tesla T4 (0)         1         7  [CUDA memcpy HtoD]
# 2.31254s  2.7956ms           (3125 1 1)        (32 1 1)        57        0B        0B         -           -           -           -     Tesla T4 (0)         1         7  _ZN6cudapy8__main__14assign_labels1B2v1B94cw51cXTLSUwv1sCUt9Uw11Ew1dRRQPKzLTg4gaGKFsG2oMQGEYakJSQB1PQBk0Bynm21OiwU1a0UoLGhDpQE8oxrNQE_3dE5ArrayIdLi2E1C7mutable7alignedE5ArrayIdLi2E1C7mutable7alignedE5ArrayIxLi1E1C7mutable7alignedEx5ArrayIdLi2E1C7mutable7alignedE [818]
# 2.31533s  4.1706ms                    -               -         -         -         -  12.970MB  3.0370GB/s      Device    Pageable     Tesla T4 (0)         1         7  [CUDA memcpy DtoH]
# 2.32000s  1.9200us                    -               -         -         -         -  2.6563KB  1.3194GB/s      Device    Pageable     Tesla T4 (0)         1         7  [CUDA memcpy DtoH]
# 2.32013s  62.654us                    -               -         -         -         -  781.25KB  11.892GB/s      Device    Pageable     Tesla T4 (0)         1         7  [CUDA memcpy DtoH]
# 2.32047s  6.1826ms                    -               -         -         -         -  15.259MB  2.4102GB/s      Device    Pageable     Tesla T4 (0)         1         7  [CUDA memcpy DtoH]
# 2.36146s  5.1390ms                    -               -         -         -         -  12.970MB  2.4647GB/s    Pageable      Device     Tesla T4 (0)         1         7  [CUDA memcpy HtoD]
# 2.36725s  1.3120us                    -               -         -         -         -  2.6563KB  1.9308GB/s    Pageable      Device     Tesla T4 (0)         1         7  [CUDA memcpy HtoD]
# 2.37192s  67.358us                    -               -         -         -         -  781.25KB  11.061GB/s    Pageable      Device     Tesla T4 (0)         1         7  [CUDA memcpy HtoD]
# 2.37397s  6.4384ms                    -               -         -         -         -  15.259MB  2.3144GB/s    Pageable      Device     Tesla T4 (0)         1         7  [CUDA memcpy HtoD]
# 2.38051s  2.8210ms           (3125 1 1)        (32 1 1)        57        0B        0B         -           -           -           -     Tesla T4 (0)         1         7  _ZN6cudapy8__main__14assign_labels1B2v1B94cw51cXTLSUwv1sCUt9Uw11Ew1dRRQPKzLTg4gaGKFsG2oMQGEYakJSQB1PQBk0Bynm21OiwU1a0UoLGhDpQE8oxrNQE_3dE5ArrayIdLi2E1C7mutable7alignedE5ArrayIdLi2E1C7mutable7alignedE5ArrayIxLi1E1C7mutable7alignedEx5ArrayIdLi2E1C7mutable7alignedE [871]
# 2.38334s  4.4740ms                    -               -         -         -         -  12.970MB  2.8310GB/s      Device    Pageable     Tesla T4 (0)         1         7  [CUDA memcpy DtoH]
# 2.38833s  2.2080us                    -               -         -         -         -  2.6563KB  1.1473GB/s      Device    Pageable     Tesla T4 (0)         1         7  [CUDA memcpy DtoH]
# 2.38846s  62.655us                    -               -         -         -         -  781.25KB  11.891GB/s      Device    Pageable     Tesla T4 (0)         1         7  [CUDA memcpy DtoH]
# 2.38989s  6.1903ms                    -               -         -         -         -  15.259MB  2.4072GB/s      Device    Pageable     Tesla T4 (0)         1         7  [CUDA memcpy DtoH]
# 2.42812s  5.2989ms                    -               -         -         -         -  12.970MB  2.3903GB/s    Pageable      Device     Tesla T4 (0)         1         7  [CUDA memcpy HtoD]
# 2.43400s     896ns                    -               -         -         -         -  2.6563KB  2.8272GB/s    Pageable      Device     Tesla T4 (0)         1         7  [CUDA memcpy HtoD]
# 2.43467s  67.615us                    -               -         -         -         -  781.25KB  11.019GB/s    Pageable      Device     Tesla T4 (0)         1         7  [CUDA memcpy HtoD]
# 2.43832s  4.9650ms                    -               -         -         -         -  15.259MB  3.0012GB/s    Pageable      Device     Tesla T4 (0)         1         7  [CUDA memcpy HtoD]
# 2.44337s  2.7916ms           (3125 1 1)        (32 1 1)        57        0B        0B         -           -           -           -     Tesla T4 (0)         1         7  _ZN6cudapy8__main__14assign_labels1B2v1B94cw51cXTLSUwv1sCUt9Uw11Ew1dRRQPKzLTg4gaGKFsG2oMQGEYakJSQB1PQBk0Bynm21OiwU1a0UoLGhDpQE8oxrNQE_3dE5ArrayIdLi2E1C7mutable7alignedE5ArrayIdLi2E1C7mutable7alignedE5ArrayIxLi1E1C7mutable7alignedEx5ArrayIdLi2E1C7mutable7alignedE [913]
# 2.44616s  3.8100ms                    -               -         -         -         -  12.970MB  3.3244GB/s      Device    Pageable     Tesla T4 (0)         1         7  [CUDA memcpy DtoH]
# 2.45047s  1.9210us                    -               -         -         -         -  2.6563KB  1.3187GB/s      Device    Pageable     Tesla T4 (0)         1         7  [CUDA memcpy DtoH]
# 2.45063s  62.718us                    -               -         -         -         -  781.25KB  11.879GB/s      Device    Pageable     Tesla T4 (0)         1         7  [CUDA memcpy DtoH]
# 2.45099s  7.2267ms                    -               -         -         -         -  15.259MB  2.0619GB/s      Device    Pageable     Tesla T4 (0)         1         7  [CUDA memcpy DtoH]
# 2.49015s  5.9198ms                    -               -         -         -         -  12.970MB  2.1396GB/s    Pageable      Device     Tesla T4 (0)         1         7  [CUDA memcpy HtoD]
# 2.49657s     864ns                    -               -         -         -         -  2.6563KB  2.9319GB/s    Pageable      Device     Tesla T4 (0)         1         7  [CUDA memcpy HtoD]
# 2.49738s  67.327us                    -               -         -         -         -  781.25KB  11.066GB/s    Pageable      Device     Tesla T4 (0)         1         7  [CUDA memcpy HtoD]
# 2.50035s  6.4785ms                    -               -         -         -         -  15.259MB  2.3001GB/s    Pageable      Device     Tesla T4 (0)         1         7  [CUDA memcpy HtoD]
# 2.50692s  2.8043ms           (3125 1 1)        (32 1 1)        57        0B        0B         -           -           -           -     Tesla T4 (0)         1         7  _ZN6cudapy8__main__14assign_labels1B2v1B94cw51cXTLSUwv1sCUt9Uw11Ew1dRRQPKzLTg4gaGKFsG2oMQGEYakJSQB1PQBk0Bynm21OiwU1a0UoLGhDpQE8oxrNQE_3dE5ArrayIdLi2E1C7mutable7alignedE5ArrayIdLi2E1C7mutable7alignedE5ArrayIxLi1E1C7mutable7alignedEx5ArrayIdLi2E1C7mutable7alignedE [955]
# 2.50973s  5.0536ms                    -               -         -         -         -  12.970MB  2.5063GB/s      Device    Pageable     Tesla T4 (0)         1         7  [CUDA memcpy DtoH]
# 2.51527s  2.1440us                    -               -         -         -         -  2.6563KB  1.1815GB/s      Device    Pageable     Tesla T4 (0)         1         7  [CUDA memcpy DtoH]
# 2.51541s  62.750us                    -               -         -         -         -  781.25KB  11.873GB/s      Device    Pageable     Tesla T4 (0)         1         7  [CUDA memcpy DtoH]
# 2.51785s  6.1994ms                    -               -         -         -         -  15.259MB  2.4036GB/s      Device    Pageable     Tesla T4 (0)         1         7  [CUDA memcpy DtoH]
# 2.55891s  2.8792ms                    -               -         -         -         -  12.970MB  4.3991GB/s    Pageable      Device     Tesla T4 (0)         1         7  [CUDA memcpy HtoD]
# 2.56226s     864ns                    -               -         -         -         -  2.6563KB  2.9319GB/s    Pageable      Device     Tesla T4 (0)         1         7  [CUDA memcpy HtoD]
# 2.56286s  67.230us                    -               -         -         -         -  781.25KB  11.082GB/s    Pageable      Device     Tesla T4 (0)         1         7  [CUDA memcpy HtoD]
# 2.56380s  3.3556ms                    -               -         -         -         -  15.259MB  4.4406GB/s    Pageable      Device     Tesla T4 (0)         1         7  [CUDA memcpy HtoD]
# 2.56723s  2.8113ms           (3125 1 1)        (32 1 1)        57        0B        0B         -           -           -           -     Tesla T4 (0)         1         7  _ZN6cudapy8__main__14assign_labels1B2v1B94cw51cXTLSUwv1sCUt9Uw11Ew1dRRQPKzLTg4gaGKFsG2oMQGEYakJSQB1PQBk0Bynm21OiwU1a0UoLGhDpQE8oxrNQE_3dE5ArrayIdLi2E1C7mutable7alignedE5ArrayIdLi2E1C7mutable7alignedE5ArrayIxLi1E1C7mutable7alignedEx5ArrayIdLi2E1C7mutable7alignedE [1008]
# 2.57004s  2.2736ms                    -               -         -         -         -  12.970MB  5.5709GB/s      Device    Pageable     Tesla T4 (0)         1         7  [CUDA memcpy DtoH]
# 2.57280s  1.9520us                    -               -         -         -         -  2.6563KB  1.2977GB/s      Device    Pageable     Tesla T4 (0)         1         7  [CUDA memcpy DtoH]
# 2.57291s  62.687us                    -               -         -         -         -  781.25KB  11.885GB/s      Device    Pageable     Tesla T4 (0)         1         7  [CUDA memcpy DtoH]
# 2.57324s  3.1808ms                    -               -         -         -         -  15.259MB  4.6847GB/s      Device    Pageable     Tesla T4 (0)         1         7  [CUDA memcpy DtoH]
# 2.59253s  3.0277ms                    -               -         -         -         -  12.970MB  4.1834GB/s    Pageable      Device     Tesla T4 (0)         1         7  [CUDA memcpy HtoD]
# 2.59600s     896ns                    -               -         -         -         -  2.6563KB  2.8272GB/s    Pageable      Device     Tesla T4 (0)         1         7  [CUDA memcpy HtoD]
# 2.59656s  67.326us                    -               -         -         -         -  781.25KB  11.066GB/s    Pageable      Device     Tesla T4 (0)         1         7  [CUDA memcpy HtoD]
# 2.59746s  3.2827ms                    -               -         -         -         -  15.259MB  4.5393GB/s    Pageable      Device     Tesla T4 (0)         1         7  [CUDA memcpy HtoD]
# 2.60081s  2.7760ms           (3125 1 1)        (32 1 1)        57        0B        0B         -           -           -           -     Tesla T4 (0)         1         7  _ZN6cudapy8__main__14assign_labels1B2v1B94cw51cXTLSUwv1sCUt9Uw11Ew1dRRQPKzLTg4gaGKFsG2oMQGEYakJSQB1PQBk0Bynm21OiwU1a0UoLGhDpQE8oxrNQE_3dE5ArrayIdLi2E1C7mutable7alignedE5ArrayIdLi2E1C7mutable7alignedE5ArrayIxLi1E1C7mutable7alignedEx5ArrayIdLi2E1C7mutable7alignedE [1050]
# 2.60359s  2.1458ms                    -               -         -         -         -  12.970MB  5.9026GB/s      Device    Pageable     Tesla T4 (0)         1         7  [CUDA memcpy DtoH]
# 2.60617s  2.1760us                    -               -         -         -         -  2.6563KB  1.1642GB/s      Device    Pageable     Tesla T4 (0)         1         7  [CUDA memcpy DtoH]
# 2.60628s  62.878us                    -               -         -         -         -  781.25KB  11.849GB/s      Device    Pageable     Tesla T4 (0)         1         7  [CUDA memcpy DtoH]
# 2.60661s  3.0842ms                    -               -         -         -         -  15.259MB  4.8314GB/s      Device    Pageable     Tesla T4 (0)         1         7  [CUDA memcpy DtoH]
# 2.62975s  2.7085ms                    -               -         -         -         -  12.970MB  4.6763GB/s    Pageable      Device     Tesla T4 (0)         1         7  [CUDA memcpy HtoD]
# 2.63303s  1.3120us                    -               -         -         -         -  2.6563KB  1.9308GB/s    Pageable      Device     Tesla T4 (0)         1         7  [CUDA memcpy HtoD]
# 2.63360s  67.166us                    -               -         -         -         -  781.25KB  11.093GB/s    Pageable      Device     Tesla T4 (0)         1         7  [CUDA memcpy HtoD]
# 2.63452s  3.3488ms                    -               -         -         -         -  15.259MB  4.4497GB/s    Pageable      Device     Tesla T4 (0)         1         7  [CUDA memcpy HtoD]
# 2.63795s  2.7836ms           (3125 1 1)        (32 1 1)        57        0B        0B         -           -           -           -     Tesla T4 (0)         1         7  _ZN6cudapy8__main__14assign_labels1B2v1B94cw51cXTLSUwv1sCUt9Uw11Ew1dRRQPKzLTg4gaGKFsG2oMQGEYakJSQB1PQBk0Bynm21OiwU1a0UoLGhDpQE8oxrNQE_3dE5ArrayIdLi2E1C7mutable7alignedE5ArrayIdLi2E1C7mutable7alignedE5ArrayIxLi1E1C7mutable7alignedEx5ArrayIdLi2E1C7mutable7alignedE [1103]
# 2.64074s  2.0808ms                    -               -         -         -         -  12.970MB  6.0869GB/s      Device    Pageable     Tesla T4 (0)         1         7  [CUDA memcpy DtoH]
# 2.64325s  1.9510us                    -               -         -         -         -  2.6563KB  1.2984GB/s      Device    Pageable     Tesla T4 (0)         1         7  [CUDA memcpy DtoH]
# 2.64337s  62.718us                    -               -         -         -         -  781.25KB  11.879GB/s      Device    Pageable     Tesla T4 (0)         1         7  [CUDA memcpy DtoH]
# 2.64369s  3.0947ms                    -               -         -         -         -  15.259MB  4.8150GB/s      Device    Pageable     Tesla T4 (0)         1         7  [CUDA memcpy DtoH]
# 2.66668s  2.7841ms                    -               -         -         -         -  12.970MB  4.5494GB/s    Pageable      Device     Tesla T4 (0)         1         7  [CUDA memcpy HtoD]
# 2.66999s     896ns                    -               -         -         -         -  2.6563KB  2.8272GB/s    Pageable      Device     Tesla T4 (0)         1         7  [CUDA memcpy HtoD]
# 2.67064s  67.135us                    -               -         -         -         -  781.25KB  11.098GB/s    Pageable      Device     Tesla T4 (0)         1         7  [CUDA memcpy HtoD]
# 2.67156s  3.3233ms                    -               -         -         -         -  15.259MB  4.4838GB/s    Pageable      Device     Tesla T4 (0)         1         7  [CUDA memcpy HtoD]
# 2.67495s  2.7800ms           (3125 1 1)        (32 1 1)        57        0B        0B         -           -           -           -     Tesla T4 (0)         1         7  _ZN6cudapy8__main__14assign_labels1B2v1B94cw51cXTLSUwv1sCUt9Uw11Ew1dRRQPKzLTg4gaGKFsG2oMQGEYakJSQB1PQBk0Bynm21OiwU1a0UoLGhDpQE8oxrNQE_3dE5ArrayIdLi2E1C7mutable7alignedE5ArrayIdLi2E1C7mutable7alignedE5ArrayIxLi1E1C7mutable7alignedEx5ArrayIdLi2E1C7mutable7alignedE [1145]
# 2.67774s  2.0733ms                    -               -         -         -         -  12.970MB  6.1091GB/s      Device    Pageable     Tesla T4 (0)         1         7  [CUDA memcpy DtoH]
# 2.68025s  2.1760us                    -               -         -         -         -  2.6563KB  1.1642GB/s      Device    Pageable     Tesla T4 (0)         1         7  [CUDA memcpy DtoH]
# 2.68038s  62.558us                    -               -         -         -         -  781.25KB  11.910GB/s      Device    Pageable     Tesla T4 (0)         1         7  [CUDA memcpy DtoH]
# 2.68070s  3.1614ms                    -               -         -         -         -  15.259MB  4.7135GB/s      Device    Pageable     Tesla T4 (0)         1         7  [CUDA memcpy DtoH]
# 2.69985s  3.0355ms                    -               -         -         -         -  12.970MB  4.1726GB/s    Pageable      Device     Tesla T4 (0)         1         7  [CUDA memcpy HtoD]
# 2.70329s  1.2810us                    -               -         -         -         -  2.6563KB  1.9775GB/s    Pageable      Device     Tesla T4 (0)         1         7  [CUDA memcpy HtoD]
# ...
# 4.07528s     864ns                    -               -         -         -         -  2.6563KB  2.9319GB/s    Pageable      Device     Tesla T4 (0)         1         7  [CUDA memcpy HtoD]
# 4.07587s  67.135us                    -               -         -         -         -  781.25KB  11.098GB/s    Pageable      Device     Tesla T4 (0)         1         7  [CUDA memcpy HtoD]
# 4.07681s  3.4009ms                    -               -         -         -         -  15.259MB  4.3816GB/s    Pageable      Device     Tesla T4 (0)         1         7  [CUDA memcpy HtoD]
# 4.08028s  2.7758ms           (3125 1 1)        (32 1 1)        57        0B        0B         -           -           -           -     Tesla T4 (0)         1         7  _ZN6cudapy8__main__14assign_labels1B2v1B94cw51cXTLSUwv1sCUt9Uw11Ew1dRRQPKzLTg4gaGKFsG2oMQGEYakJSQB1PQBk0Bynm21OiwU1a0UoLGhDpQE8oxrNQE_3dE5ArrayIdLi2E1C7mutable7alignedE5ArrayIdLi2E1C7mutable7alignedE5ArrayIxLi1E1C7mutable7alignedEx5ArrayIdLi2E1C7mutable7alignedE [2937]
# 4.08306s  2.0759ms                    -               -         -         -         -  12.970MB  6.1015GB/s      Device    Pageable     Tesla T4 (0)         1         7  [CUDA memcpy DtoH]
# 4.08560s  1.9200us                    -               -         -         -         -  2.6563KB  1.3194GB/s      Device    Pageable     Tesla T4 (0)         1         7  [CUDA memcpy DtoH]
# 4.08572s  62.655us                    -               -         -         -         -  781.25KB  11.891GB/s      Device    Pageable     Tesla T4 (0)         1         7  [CUDA memcpy DtoH]
# 4.08603s  3.1462ms                    -               -         -         -         -  15.259MB  4.7362GB/s      Device    Pageable     Tesla T4 (0)         1         7  [CUDA memcpy DtoH]
# 4.10572s  2.7322ms                    -               -         -         -         -  12.970MB  4.6358GB/s    Pageable      Device     Tesla T4 (0)         1         7  [CUDA memcpy HtoD]
# 4.10890s     896ns                    -               -         -         -         -  2.6563KB  2.8272GB/s    Pageable      Device     Tesla T4 (0)         1         7  [CUDA memcpy HtoD]
# 4.10965s  67.230us                    -               -         -         -         -  781.25KB  11.082GB/s    Pageable      Device     Tesla T4 (0)         1         7  [CUDA memcpy HtoD]
# 4.11057s  3.2948ms                    -               -         -         -         -  15.259MB  4.5226GB/s    Pageable      Device     Tesla T4 (0)         1         7  [CUDA memcpy HtoD]
# 4.11395s  2.8099ms           (3125 1 1)        (32 1 1)        57        0B        0B         -           -           -           -     Tesla T4 (0)         1         7  _ZN6cudapy8__main__14assign_labels1B2v1B94cw51cXTLSUwv1sCUt9Uw11Ew1dRRQPKzLTg4gaGKFsG2oMQGEYakJSQB1PQBk0Bynm21OiwU1a0UoLGhDpQE8oxrNQE_3dE5ArrayIdLi2E1C7mutable7alignedE5ArrayIdLi2E1C7mutable7alignedE5ArrayIxLi1E1C7mutable7alignedEx5ArrayIdLi2E1C7mutable7alignedE [2979]
# 4.11677s  2.0577ms                    -               -         -         -         -  12.970MB  6.1555GB/s      Device    Pageable     Tesla T4 (0)         1         7  [CUDA memcpy DtoH]
# 4.11926s  2.1440us                    -               -         -         -         -  2.6563KB  1.1815GB/s      Device    Pageable     Tesla T4 (0)         1         7  [CUDA memcpy DtoH]
# 4.11939s  62.655us                    -               -         -         -         -  781.25KB  11.891GB/s      Device    Pageable     Tesla T4 (0)         1         7  [CUDA memcpy DtoH]
# 4.11970s  3.1530ms                    -               -         -         -         -  15.259MB  4.7261GB/s      Device    Pageable     Tesla T4 (0)         1         7  [CUDA memcpy DtoH]
# 4.14353s  2.8910ms                    -               -         -         -         -  12.970MB  4.3812GB/s    Pageable      Device     Tesla T4 (0)         1         7  [CUDA memcpy HtoD]
# 4.14691s     864ns                    -               -         -         -         -  2.6563KB  2.9319GB/s    Pageable      Device     Tesla T4 (0)         1         7  [CUDA memcpy HtoD]
# 4.14748s  67.422us                    -               -         -         -         -  781.25KB  11.051GB/s    Pageable      Device     Tesla T4 (0)         1         7  [CUDA memcpy HtoD]
# 4.14838s  3.4356ms                    -               -         -         -         -  15.259MB  4.3372GB/s    Pageable      Device     Tesla T4 (0)         1         7  [CUDA memcpy HtoD]
# 4.15189s  2.8108ms           (3125 1 1)        (32 1 1)        57        0B        0B         -           -           -           -     Tesla T4 (0)         1         7  _ZN6cudapy8__main__14assign_labels1B2v1B94cw51cXTLSUwv1sCUt9Uw11Ew1dRRQPKzLTg4gaGKFsG2oMQGEYakJSQB1PQBk0Bynm21OiwU1a0UoLGhDpQE8oxrNQE_3dE5ArrayIdLi2E1C7mutable7alignedE5ArrayIdLi2E1C7mutable7alignedE5ArrayIxLi1E1C7mutable7alignedEx5ArrayIdLi2E1C7mutable7alignedE [3032]
# 4.15470s  1.9806ms                    -               -         -         -         -  12.970MB  6.3952GB/s      Device    Pageable     Tesla T4 (0)         1         7  [CUDA memcpy DtoH]
# 4.15713s  2.1120us                    -               -         -         -         -  2.6563KB  1.1994GB/s      Device    Pageable     Tesla T4 (0)         1         7  [CUDA memcpy DtoH]
# 4.15724s  62.686us                    -               -         -         -         -  781.25KB  11.886GB/s      Device    Pageable     Tesla T4 (0)         1         7  [CUDA memcpy DtoH]
# 4.15757s  3.1885ms                    -               -         -         -         -  15.259MB  4.6734GB/s      Device    Pageable     Tesla T4 (0)         1         7  [CUDA memcpy DtoH]
# 4.17892s  2.7588ms                    -               -         -         -         -  12.970MB  4.5911GB/s    Pageable      Device     Tesla T4 (0)         1         7  [CUDA memcpy HtoD]
# 4.18212s     896ns                    -               -         -         -         -  2.6563KB  2.8272GB/s    Pageable      Device     Tesla T4 (0)         1         7  [CUDA memcpy HtoD]
# 4.18271s  67.358us                    -               -         -         -         -  781.25KB  11.061GB/s    Pageable      Device     Tesla T4 (0)         1         7  [CUDA memcpy HtoD]
# 4.18363s  3.2942ms                    -               -         -         -         -  15.259MB  4.5235GB/s    Pageable      Device     Tesla T4 (0)         1         7  [CUDA memcpy HtoD]
# 4.18700s  2.7733ms           (3125 1 1)        (32 1 1)        57        0B        0B         -           -           -           -     Tesla T4 (0)         1         7  _ZN6cudapy8__main__14assign_labels1B2v1B94cw51cXTLSUwv1sCUt9Uw11Ew1dRRQPKzLTg4gaGKFsG2oMQGEYakJSQB1PQBk0Bynm21OiwU1a0UoLGhDpQE8oxrNQE_3dE5ArrayIdLi2E1C7mutable7alignedE5ArrayIdLi2E1C7mutable7alignedE5ArrayIxLi1E1C7mutable7alignedEx5ArrayIdLi2E1C7mutable7alignedE [3074]
# 4.18978s  2.0148ms                    -               -         -         -         -  12.970MB  6.2864GB/s      Device    Pageable     Tesla T4 (0)         1         7  [CUDA memcpy DtoH]
# 4.19225s  2.2080us                    -               -         -         -         -  2.6563KB  1.1473GB/s      Device    Pageable     Tesla T4 (0)         1         7  [CUDA memcpy DtoH]
# 4.19237s  62.719us                    -               -         -         -         -  781.25KB  11.879GB/s      Device    Pageable     Tesla T4 (0)         1         7  [CUDA memcpy DtoH]
# 4.19280s  3.5866ms                    -               -         -         -         -  15.259MB  4.1547GB/s      Device    Pageable     Tesla T4 (0)         1         7  [CUDA memcpy DtoH]
# 4.23911s  8.5082ms                    -               -         -         -         -  12.970MB  1.4887GB/s    Pageable      Device     Tesla T4 (0)         1         7  [CUDA memcpy HtoD]
# 4.24826s  1.3110us                    -               -         -         -         -  2.6563KB  1.9323GB/s    Pageable      Device     Tesla T4 (0)         1         7  [CUDA memcpy HtoD]
# 4.24888s  67.166us                    -               -         -         -         -  781.25KB  11.093GB/s    Pageable      Device     Tesla T4 (0)         1         7  [CUDA memcpy HtoD]
# 4.24978s  8.9189ms                    -               -         -         -         -  15.259MB  1.6707GB/s    Pageable      Device     Tesla T4 (0)         1         7  [CUDA memcpy HtoD]
# 4.25878s  2.7982ms           (3125 1 1)        (32 1 1)        57        0B        0B         -           -           -           -     Tesla T4 (0)         1         7  _ZN6cudapy8__main__14assign_labels1B2v1B94cw51cXTLSUwv1sCUt9Uw11Ew1dRRQPKzLTg4gaGKFsG2oMQGEYakJSQB1PQBk0Bynm21OiwU1a0UoLGhDpQE8oxrNQE_3dE5ArrayIdLi2E1C7mutable7alignedE5ArrayIdLi2E1C7mutable7alignedE5ArrayIxLi1E1C7mutable7alignedEx5ArrayIdLi2E1C7mutable7alignedE [3127]
# 4.26159s  11.423ms                    -               -         -         -         -  12.970MB  1.1088GB/s      Device    Pageable     Tesla T4 (0)         1         7  [CUDA memcpy DtoH]
# 4.27358s  1.9840us                    -               -         -         -         -  2.6563KB  1.2768GB/s      Device    Pageable     Tesla T4 (0)         1         7  [CUDA memcpy DtoH]
# 4.27371s  62.719us                    -               -         -         -         -  781.25KB  11.879GB/s      Device    Pageable     Tesla T4 (0)         1         7  [CUDA memcpy DtoH]
# 4.27410s  3.2329ms                    -               -         -         -         -  15.259MB  4.6092GB/s      Device    Pageable     Tesla T4 (0)         1         7  [CUDA memcpy DtoH]
# 4.31271s  3.7542ms                    -               -         -         -         -  12.970MB  3.3739GB/s    Pageable      Device     Tesla T4 (0)         1         7  [CUDA memcpy HtoD]
# 4.31692s     864ns                    -               -         -         -         -  2.6563KB  2.9319GB/s    Pageable      Device     Tesla T4 (0)         1         7  [CUDA memcpy HtoD]
# 4.31746s  67.454us                    -               -         -         -         -  781.25KB  11.045GB/s    Pageable      Device     Tesla T4 (0)         1         7  [CUDA memcpy HtoD]
# 4.31834s  11.942ms                    -               -         -         -         -  15.259MB  1.2478GB/s    Pageable      Device     Tesla T4 (0)         1         7  [CUDA memcpy HtoD]
# 4.33056s  2.7854ms           (3125 1 1)        (32 1 1)        57        0B        0B         -           -           -           -     Tesla T4 (0)         1         7  _ZN6cudapy8__main__14assign_labels1B2v1B94cw51cXTLSUwv1sCUt9Uw11Ew1dRRQPKzLTg4gaGKFsG2oMQGEYakJSQB1PQBk0Bynm21OiwU1a0UoLGhDpQE8oxrNQE_3dE5ArrayIdLi2E1C7mutable7alignedE5ArrayIdLi2E1C7mutable7alignedE5ArrayIxLi1E1C7mutable7alignedEx5ArrayIdLi2E1C7mutable7alignedE [3169]
# 4.33335s  5.2844ms                    -               -         -         -         -  12.970MB  2.3969GB/s      Device    Pageable     Tesla T4 (0)         1         7  [CUDA memcpy DtoH]
# 4.33990s  2.1750us                    -               -         -         -         -  2.6563KB  1.1647GB/s      Device    Pageable     Tesla T4 (0)         1         7  [CUDA memcpy DtoH]
# 4.34022s  62.686us                    -               -         -         -         -  781.25KB  11.886GB/s      Device    Pageable     Tesla T4 (0)         1         7  [CUDA memcpy DtoH]
# 4.34103s  4.9333ms                    -               -         -         -         -  15.259MB  3.0206GB/s      Device    Pageable     Tesla T4 (0)         1         7  [CUDA memcpy DtoH]
# 4.36240s  2.7794ms                    -               -         -         -         -  12.970MB  4.5571GB/s    Pageable      Device     Tesla T4 (0)         1         7  [CUDA memcpy HtoD]
# 4.36561s  1.3110us                    -               -         -         -         -  2.6563KB  1.9323GB/s    Pageable      Device     Tesla T4 (0)         1         7  [CUDA memcpy HtoD]
# 4.36635s  67.646us                    -               -         -         -         -  781.25KB  11.014GB/s    Pageable      Device     Tesla T4 (0)         1         7  [CUDA memcpy HtoD]
# 4.36725s  3.3948ms                    -               -         -         -         -  15.259MB  4.3894GB/s    Pageable      Device     Tesla T4 (0)         1         7  [CUDA memcpy HtoD]
# 4.37071s  2.7841ms           (3125 1 1)        (32 1 1)        57        0B        0B         -           -           -           -     Tesla T4 (0)         1         7  _ZN6cudapy8__main__14assign_labels1B2v1B94cw51cXTLSUwv1sCUt9Uw11Ew1dRRQPKzLTg4gaGKFsG2oMQGEYakJSQB1PQBk0Bynm21OiwU1a0UoLGhDpQE8oxrNQE_3dE5ArrayIdLi2E1C7mutable7alignedE5ArrayIdLi2E1C7mutable7alignedE5ArrayIxLi1E1C7mutable7alignedEx5ArrayIdLi2E1C7mutable7alignedE [3211]
# 4.37350s  2.3595ms                    -               -         -         -         -  12.970MB  5.3682GB/s      Device    Pageable     Tesla T4 (0)         1         7  [CUDA memcpy DtoH]
# 4.37633s  1.9200us                    -               -         -         -         -  2.6563KB  1.3194GB/s      Device    Pageable     Tesla T4 (0)         1         7  [CUDA memcpy DtoH]
# 4.37644s  62.622us                    -               -         -         -         -  781.25KB  11.898GB/s      Device    Pageable     Tesla T4 (0)         1         7  [CUDA memcpy DtoH]
# 4.37676s  3.0602ms                    -               -         -         -         -  15.259MB  4.8693GB/s      Device    Pageable     Tesla T4 (0)         1         7  [CUDA memcpy DtoH]
# 4.39953s  2.7945ms                    -               -         -         -         -  12.970MB  4.5325GB/s    Pageable      Device     Tesla T4 (0)         1         7  [CUDA memcpy HtoD]
# 4.40294s  1.3120us                    -               -         -         -         -  2.6563KB  1.9308GB/s    Pageable      Device     Tesla T4 (0)         1         7  [CUDA memcpy HtoD]
# 4.40350s  67.039us                    -               -         -         -         -  781.25KB  11.114GB/s    Pageable      Device     Tesla T4 (0)         1         7  [CUDA memcpy HtoD]
# 4.40440s  3.3311ms                    -               -         -         -         -  15.259MB  4.4734GB/s    Pageable      Device     Tesla T4 (0)         1         7  [CUDA memcpy HtoD]
# 4.40781s  2.8353ms           (3125 1 1)        (32 1 1)        57        0B        0B         -           -           -           -     Tesla T4 (0)         1         7  _ZN6cudapy8__main__14assign_labels1B2v1B94cw51cXTLSUwv1sCUt9Uw11Ew1dRRQPKzLTg4gaGKFsG2oMQGEYakJSQB1PQBk0Bynm21OiwU1a0UoLGhDpQE8oxrNQE_3dE5ArrayIdLi2E1C7mutable7alignedE5ArrayIdLi2E1C7mutable7alignedE5ArrayIxLi1E1C7mutable7alignedEx5ArrayIdLi2E1C7mutable7alignedE [3264]
# 4.41065s  2.2467ms                    -               -         -         -         -  12.970MB  5.6377GB/s      Device    Pageable     Tesla T4 (0)         1         7  [CUDA memcpy DtoH]
# 4.41338s  2.1760us                    -               -         -         -         -  2.6563KB  1.1642GB/s      Device    Pageable     Tesla T4 (0)         1         7  [CUDA memcpy DtoH]
# 4.41351s  62.654us                    -               -         -         -         -  781.25KB  11.892GB/s      Device    Pageable     Tesla T4 (0)         1         7  [CUDA memcpy DtoH]
# 4.41385s  3.1278ms                    -               -         -         -         -  15.259MB  4.7641GB/s      Device    Pageable     Tesla T4 (0)         1         7  [CUDA memcpy DtoH]
#
# Regs: Number of registers used per CUDA thread. This number includes registers used internally by the CUDA driver and/or tools and can be more than what the compiler shows.
# SSMem: Static shared memory allocated per CUDA block.
# DSMem: Dynamic shared memory allocated per CUDA block.
# SrcMemType: The type of source memory accessed by memory operation/copy
# DstMemType: The type of destination memory accessed by memory operation/copy

# %% [markdown]
# Ta tiến hành xem thông tin của phiên bản song song cơ bản trước qua câu lệnh `nvprof`, ta thấy được:
#
# Các mảng `X`, `centers`, `labels`, `dis_arr` luôn được Numba tự động copy từ bộ nhớ của CPU/host sang bộ nhớ của GPU/device. Khi các thread bên GPU/device chạy xong hàm kernel thì Numba lại tự động copy toàn bộ các mảng đó từ GPU/device về bộ nhớ của CPU/host => Việc copy như vậy là dư thừa nên ta có thể tối ưu hóa phần này để tăng tốc.
#
# Từ đó, ta nên tối ưu bằng cách:
# + Copy từ bộ nhớ của CPU/host sang bộ nhớ của GPU/device: `X`, `centers`, `dis_arr`
# + Copy từ bộ nhớ của GPU/device về bộ nhớ của CPU/host: `labels`

# %% [markdown]
# #### Thiết kế

# %% [markdown]
# Ta sẽ viết lại hàm `fit` để tối ưu lại quá trình chuyển đổi.
# - Input: X(các điểm dữ liệu đầu vào), centers(các trung tâm), k(số cụm), dis_arr(array khoảng cách giữa 1 điểm dữ liệu và các trung tâm)
#
# (Lưu ý: Vì cài đặt trong class nên hàm `fit` sẽ có khác biệt)
# - Các bước thực hiện:
#   + Copy dữ liệu từ `X`, `centers` và `dis_arr` ở bộ nhớ của CPU/host sang `d_X`, `d_centers` và `d_dis_arr` ở bộ nhớ của GPU/device
#   + Cấp phát vùng nhớ ở GPU/device cho `d_labels`
#   + Gọi hàm kernel `assign_labels[grid_size, block_size](d_X, d_centers, d_labels, k, d_dis_arr)`(Hàm này được viết tương tự như phiên bản song song cơ bản)
#   + Copy kết quả từ `d_labels` ở bộ nhớ của GPU/device về `labels` ở bộ nhớ của CPU/host
# - Output: Kết quả cuối cùng: Mảng `labels` xác định nhãn cho các điểm dữ liệu, mảng `centers` xác định trung tâm các cụm

# %% [markdown]
# #### Cài đặt

# %%
# assign label for each point
@cuda.jit
def assign_labels(X, centers, labels, k, dis_arr):
  index = cuda.grid(1)
  dim = X.shape[1]

  if index < X.shape[0]:
    for idx_k in prange(k):
      dis = 0
      for i in range(dim):
        dis += (X[index, i] - centers[idx_k, i])**2
      dis_arr[index][idx_k] = dis

    idx_min = 0
    for i in range(1, k):
      if dis_arr[index, i] < dis_arr[index, idx_min]:
        idx_min = i

    labels[index] = idx_min

# %%
class K_Means_OPT1:
  # init parameter of class
  def __init__(self, k):
    self.k = k
    self.num_loop = 0

  # chooose random k of center from X
  def init_center(self, X):
    return X[:self.k]

  def cal_new_center(self, X):
    # Tạo ma trận nhãn one-hot
    one_hot_labels = np.eye(self.k)[self.labels]

    # Tính toán tổng theo cụm
    cluster_sums = np.dot(one_hot_labels.T, X)

    # Đếm số điểm trong mỗi cụm
    cluster_counts = np.sum(one_hot_labels, axis=0)

    # Tránh chia cho 0
    cluster_counts[cluster_counts == 0] = 1

    # Tính trung tâm mới của các cụm
    new_centers = cluster_sums / cluster_counts[:, None]

    return new_centers

  def fit(self, X):
    # khởi tạo các mảng numpy cần thiết
    start_init = time.time()
    X = np.ascontiguousarray(X)
    self.centers = self.init_center(X);
    # self.labels = np.zeros(len(X), dtype=int)
    # dis_arr = np.zeros((X.shape[0], k), dtype=float)

    block_size = (32,)
    grid_size = (math.ceil(len(X) / block_size[0]),)

    # Khởi tạo các mốc thời gian
    self.assign_time = self.cal_ncenter_time = self.check_time = 0

    d_X = cuda.to_device(X)
    d_centers = cuda.to_device(self.centers)

    d_dis_arr = cuda.device_array((X.shape[0], self.k), dtype=float)
    d_labels = cuda.device_array((X.shape[0], ), dtype=int)

    end_init = time.time()
    self.init_time = end_init - start_init

    while(1):
    # for i in range(2):
      self.num_loop += 1
      start_assign = time.time()

      # call kernel

      assign_labels[grid_size, block_size](d_X, d_centers, d_labels, self.k, d_dis_arr)
      cuda.synchronize()
      self.labels = d_labels.copy_to_host()

      start_cal_ncenter = time.time()
      new_centers = self.cal_new_center(X)

      start_check = time.time()
      if np.all(new_centers == self.centers):
        break
        # print("ok")
      else:
        self.centers = new_centers

      end_loop = time.time()

      self.assign_time += (start_cal_ncenter - start_assign)
      self.cal_ncenter_time += (start_check - start_cal_ncenter)
      self.check_time += (end_loop - start_check)
    return self

# %%
# small data to compile
x_test = np.random.rand(10,2)
km_test= K_Means_OPT1(k=10)
res_test = km_test.fit(x_test)

# %%
km = K_Means_OPT1(k = 20)
res_popt1 = km.fit(X)

# %% [markdown]
# #### Đánh giá

# %% [markdown]
# ##### Thời gian chạy

# %%
# !gdown https://drive.google.com/uc?id=1Jq9hmx_4AHUGQcdrDIe_dMxarczRpzSv
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1Jq9hmx_4AHUGQcdrDIe_dMxarczRpzSv
# From (redirected): https://drive.google.com/uc?id=1Jq9hmx_4AHUGQcdrDIe_dMxarczRpzSv&confirm=t&uuid=e61cb885-2829-441d-853b-89d544b7fa40
# To: /content/parallel.py
# 100% 2.93k/2.93k [00:00<00:00, 16.8MB/s]

# %%
# !nvprof --print-gpu-trace python parallel.py
# Out:
# ==5292== NVPROF is profiling process 5292, command: python3 parallel.py
# /usr/local/lib/python3.10/dist-packages/numba/cuda/dispatcher.py:536: NumbaPerformanceWarning: Grid size 1 will likely result in GPU under-utilization due to low occupancy.
#   warn(NumbaPerformanceWarning(msg))
# ==5292== Profiling application: python3 parallel.py
# ==5292== Profiling result:
#    Start  Duration            Grid Size      Block Size     Regs*    SSMem*    DSMem*      Size  Throughput  SrcMemType  DstMemType           Device   Context    Stream  Name
# 303.65ms  1.2170us                    -               -         -         -         -      160B  125.38MB/s    Pageable      Device     Tesla T4 (0)         1         7  [CUDA memcpy HtoD]
# 303.94ms     672ns                    -               -         -         -         -      160B  227.07MB/s    Pageable      Device     Tesla T4 (0)         1         7  [CUDA memcpy HtoD]
# 734.60ms  14.432us              (1 1 1)        (32 1 1)        57        0B        0B         -           -           -           -     Tesla T4 (0)         1         7  _ZN6cudapy8__main__13assign_labelsB2v1B94cw51cXTLSUwv1sCUt9Uw11Ew1dRRQPKzLTg4gaGKFsG2oMQGEYakJSQB1PQBk0Bynm21OiwU1a0UoLGhDpQE8oxrNQE_3dE5ArrayIdLi2E1C7mutable7alignedE5ArrayIdLi2E1C7mutable7alignedE5ArrayIxLi1E1C7mutable7alignedEx5ArrayIdLi2E1C7mutable7alignedE [84]
# 734.77ms  2.0800us                    -               -         -         -         -       80B  36.680MB/s      Device    Pageable     Tesla T4 (0)         1         7  [CUDA memcpy DtoH]
# 965.97ms  2.6133ms                    -               -         -         -         -  12.970MB  4.8467GB/s    Pageable      Device     Tesla T4 (0)         1         7  [CUDA memcpy HtoD]
# 969.20ms     896ns                    -               -         -         -         -  2.6563KB  2.8272GB/s    Pageable      Device     Tesla T4 (0)         1         7  [CUDA memcpy HtoD]
# 970.02ms  2.8005ms           (3125 1 1)        (32 1 1)        57        0B        0B         -           -           -           -     Tesla T4 (0)         1         7  _ZN6cudapy8__main__13assign_labelsB2v1B94cw51cXTLSUwv1sCUt9Uw11Ew1dRRQPKzLTg4gaGKFsG2oMQGEYakJSQB1PQBk0Bynm21OiwU1a0UoLGhDpQE8oxrNQE_3dE5ArrayIdLi2E1C7mutable7alignedE5ArrayIdLi2E1C7mutable7alignedE5ArrayIxLi1E1C7mutable7alignedEx5ArrayIdLi2E1C7mutable7alignedE [107]
# 972.96ms  62.398us                    -               -         -         -         -  781.25KB  11.940GB/s      Device    Pageable     Tesla T4 (0)         1         7  [CUDA memcpy DtoH]
# 1.00113s  2.8050ms           (3125 1 1)        (32 1 1)        57        0B        0B         -           -           -           -     Tesla T4 (0)         1         7  _ZN6cudapy8__main__13assign_labelsB2v1B94cw51cXTLSUwv1sCUt9Uw11Ew1dRRQPKzLTg4gaGKFsG2oMQGEYakJSQB1PQBk0Bynm21OiwU1a0UoLGhDpQE8oxrNQE_3dE5ArrayIdLi2E1C7mutable7alignedE5ArrayIdLi2E1C7mutable7alignedE5ArrayIxLi1E1C7mutable7alignedEx5ArrayIdLi2E1C7mutable7alignedE [116]
# 1.00404s  63.295us                    -               -         -         -         -  781.25KB  11.771GB/s      Device    Pageable     Tesla T4 (0)         1         7  [CUDA memcpy DtoH]
#
# Regs: Number of registers used per CUDA thread. This number includes registers used internally by the CUDA driver and/or tools and can be more than what the compiler shows.
# SSMem: Static shared memory allocated per CUDA block.
# DSMem: Dynamic shared memory allocated per CUDA block.
# SrcMemType: The type of source memory accessed by memory operation/copy
# DstMemType: The type of destination memory accessed by memory operation/copy

# %% [markdown]
# **Nhận xét:** Ta thấy lúc này ta thấy mỗi khi hàm fit được gọi chỉ có hai lần thực hiện copy từ host sang device và mỗi lần kernel được chạy chỉ thực copy duy nhất 1 vùng dữ liệu từ device sang host

# %%
total_time = res_popt1.assign_time + res_popt1.cal_ncenter_time + res_popt1.check_time + res_popt1.init_time
print("Thời gian khởi tạo: ", res_popt1.init_time)
print("Thời gian phân cụm: ", res_popt1.assign_time)
print("Thời gian tính các trung tâm mới: ", res_popt1.cal_ncenter_time)
print("Thời gian kiểm tra sự thay đổi các trung tâm: ", res_popt1.check_time)
print("Tổng thời gian: ", total_time)

all_results.loc['parallel opt 1: opt convert process', 'time (s)'] = total_time
all_results
# Out:
# Thời gian khởi tạo:  0.0054302215576171875
# Thời gian phân cụm:  0.003489255905151367
# Thời gian tính các trung tâm mới:  0.016344308853149414
# Thời gian kiểm tra sự thay đổi các trung tâm:  3.838539123535156e-05
# Tổng thời gian:  0.02530217170715332
#                                        time (s)
# use library                            0.622627
# sequential                           819.526603
# parallel basic                        14.162330
# parallel basic + opt cal center        2.871767
# parallel basic 2                       3.050100
# parallel opt 1: opt convert process    0.025302

# %% [markdown]
# ##### Tính đúng đắn

# %%
np.sum(res_popt1.labels == correct_labels)
# Out:
# 27875

# %% [markdown]
# ### Phiên bản tối ưu 2: Trong `assign_labels` bỏ centers vào SMEM

# %% [markdown]
# #### Phân tích

# %% [markdown]
# Ta sẽ tập trung tối ưu hóa hàm kernel `assign_labels` do hàm này chiếm thời gian chạy nhiều nhất. Để ý thấy mảng `centers` trong mỗi lần lặp đều không thay đổi. Vì thế ta tiến hành lưu centers vào SMEM để giảm số lần truy xuất trong GMEM

# %% [markdown]
# #### Thiết kế

# %% [markdown]
# Ta sẽ viết lại hàm `assign_label_opt1` để thêm `centers` vào SMEM.
# - Input: X(các điểm dữ liệu đầu vào), centers(các trung tâm), k(số cụm), dis_arr(array khoảng cách giữa 1 điểm dữ liệu và các trung tâm)
#
# - Các bước thực hiện:
#   + Ta thực hiện lưu dữ liệu của `centers` vào `smem_centers` của  bộ nhớ SMEM
#   + Tiếp theo tương tự như hàm `assign_label` của phiên bản song song cơ bản, tuy nhiên khi tính khoảng cách thì ta sử dụng `smem_centers` thay vì `centers`
# - Output: Mảng `labels` xác định nhãn cho các điểm dữ liệu

# %% [markdown]
# #### Cài đặt

# %%
# assign label for each point
@cuda.jit
def assign_labels_opt1(X, centers, labels, k, dis_arr):
    index = cuda.grid(1)
    dim = X.shape[1]
    smem_centers = cuda.shared.array(shape=(32, 32), dtype=centers.dtype)  # Khai báo Shared Memory cho centers

    # Sao chép dữ liệu từ mảng centers vào Shared Memory
    if cuda.threadIdx.x < k:
        for i in range(dim):
            smem_centers[cuda.threadIdx.x, i] = centers[cuda.threadIdx.x, i]

    # if index < k * dim:
    #   row = index // dim
    #   col = index % dim
    #   smem_centers[row, col] = centers[row, col]


    cuda.syncthreads()  # Đảm bảo dữ liệu đã được sao chép vào Shared Memory trước khi sử dụng

    if index < X.shape[0]:
        for idx_k in prange(k):
            dis = 0
            for i in range(dim):
                # Sử dụng dữ liệu từ Shared Memory thay vì truy cập trực tiếp từ bộ nhớ toàn cục
                dis += (X[index, i] - smem_centers[idx_k, i])**2
            dis_arr[index][idx_k] = dis

        idx_min = 0
        for i in range(1, k):
            if dis_arr[index, i] < dis_arr[index, idx_min]:
                idx_min = i

        labels[index] = idx_min

# %%
class K_Means_OPT2:
  # init parameter of class
  def __init__(self, k):
    self.k = k
    self.num_loop = 0

  # chooose random k of center from X
  def init_center(self, X):
    return X[:self.k]

  def cal_new_center(self, X):
    # Tạo ma trận nhãn one-hot
    one_hot_labels = np.eye(self.k)[self.labels]

    # Tính toán tổng theo cụm
    cluster_sums = np.dot(one_hot_labels.T, X)

    # Đếm số điểm trong mỗi cụm
    cluster_counts = np.sum(one_hot_labels, axis=0)

    # Tránh chia cho 0
    cluster_counts[cluster_counts == 0] = 1

    # Tính trung tâm mới của các cụm
    new_centers = cluster_sums / cluster_counts[:, None]

    return new_centers

  def fit(self, X):
    # khởi tạo các mảng numpy cần thiết
    start_init = time.time()
    X = np.ascontiguousarray(X)
    self.centers = self.init_center(X);
    self.labels = np.zeros(len(X), dtype=int)
    dis_arr = np.zeros((X.shape[0], k), dtype=float)

    block_size = (32,)
    grid_size = (math.ceil(len(X) / block_size[0]),)

    # Khởi tạo các mốc thời gian
    self.assign_time = self.cal_ncenter_time = self.check_time = 0
    end_init = time.time()
    self.init_time = end_init - start_init

    while(1):
    # for i in range(2):
      self.num_loop += 1
      start_assign = time.time()

      # call kernel
      assign_labels_opt1[grid_size, block_size](X, self.centers, self.labels, self.k, dis_arr)
      cuda.synchronize()

      start_cal_ncenter = time.time()
      new_centers = self.cal_new_center(X)

      start_check = time.time()
      if np.all(new_centers == self.centers):
        break
        # print("ok")
      else:
        self.centers = new_centers

      end_loop = time.time()

      self.assign_time += (start_cal_ncenter - start_assign)
      self.cal_ncenter_time += (start_check - start_cal_ncenter)
      self.check_time += (end_loop - start_check)
    return self

# %%
# small data to compile
x_test = np.random.rand(10,2)
km_test= K_Means_OPT2(k=10)
res_test = km_test.fit(x_test)

# %%
km = K_Means_OPT2(k = 20)
res_popt2 = km.fit(X)

# %% [markdown]
# #### Đánh giá

# %% [markdown]
# ##### Thời gian chạy

# %%
total_time = res_popt2.assign_time + res_popt2.cal_ncenter_time + res_popt2.check_time + res_popt2.init_time
print("Thời gian khởi tạo: ", res_popt2.init_time)
print("Thời gian phân cụm: ", res_popt2.assign_time)
print("Thời gian tính các trung tâm mới: ", res_popt2.cal_ncenter_time)
print("Thời gian kiểm tra sự thay đổi các trung tâm: ", res_popt2.check_time)
print("Tổng thời gian: ", total_time)

all_results.loc['parallel opt 2: SMEM', 'time (s)'] = total_time
all_results
# Out:
# Thời gian khởi tạo:  0.002268075942993164
# Thời gian phân cụm:  1.5494234561920166
# Thời gian tính các trung tâm mới:  1.1581969261169434
# Thời gian kiểm tra sự thay đổi các trung tâm:  0.0019538402557373047
# Tổng thời gian:  2.7118422985076904
#                                        time (s)
# use library                            0.622627
# sequential                           819.526603
# parallel basic                        14.162330
# parallel basic + opt cal center        2.871767
# parallel basic 2                       3.050100
# parallel opt 1: opt convert process    0.025302
# parallel opt 2: SMEM                   2.711842

# %% [markdown]
# ##### Tính đúng đắn

# %%
np.sum(res_popt2.labels == correct_labels)
# Out:
# 100000

# %% [markdown]
# ### Phiên bản tối ưu 3: Trong `assign_labels` bỏ centers vào CMEM

# %% [markdown]
# #### Phân tích

# %% [markdown]
# Ta sẽ tập trung tối ưu hóa hàm kernel `assign_labels` do hàm này chiếm thời gian chạy nhiều nhất. Để ý thấy mảng `centers` trong mỗi lần lặp đều không thay đổi. Vì thế ta tiến hành lưu centers vào CMEM để giảm số lần truy xuất trong GMEM

# %% [markdown]
# #### Thiết kế

# %% [markdown]
# Ta sẽ viết lại hàm `assign_label_opt2` để thêm `centers` vào CMEM.
# - Input: X(các điểm dữ liệu đầu vào), centers(các trung tâm), k(số cụm), dis_arr(array khoảng cách giữa 1 điểm dữ liệu và các trung tâm)
#
# - Các bước thực hiện:
#   + Ta thực hiện lưu dữ liệu của `centers` vào `cmem_centers` của  bộ nhớ CMEM (Vì cú pháp để thực hiện gọi CMEM trong cuda Numba phải gọi trong hàm của device không ở host nên phải viết thêm 1 hàm để hình thành CMEM cho `centers`)
#   + Tiếp theo tương tự như hàm `assign_label` của phiên bản song song cơ bản, tuy nhiên khi tính khoảng cách thì ta sử dụng `cmem_centers` thay vì `centers`
# - Output: Mảng `labels` xác định nhãn cho các điểm dữ liệu

# %% [markdown]
# #### Cài đặt

# %%
@cuda.jit
def constant_array(X, centers):
    index = cuda.grid(1)
    dim = X.shape[1]

    # Sao chép dữ liệu từ mảng centers vào constant memory
    if cuda.threadIdx.x < k:
        for i in range(dim):
            cuda.const.array_like(centers)[cuda.threadIdx.x, i] = centers[cuda.threadIdx.x, i]

# %%
@cuda.jit
def assign_labels_opt2(X, centers, labels, k, dis_arr):
    index = cuda.grid(1)
    dim = X.shape[1]

    # Sao chép dữ liệu từ mảng centers vào constant memory
    # if cuda.threadIdx.x < k:
    #     for i in range(dim):
    #         cuda.const.array_like(centers)[cuda.threadIdx.x, i] = centers[cuda.threadIdx.x, i]

    cuda.syncthreads()  # Đảm bảo dữ liệu đã được sao chép vào constant memory trước khi sử dụng

    if index < X.shape[0]:
        for idx_k in prange(k):
            dis = 0
            for i in range(dim):
                # Sử dụng dữ liệu từ constant memory thay vì truy cập trực tiếp từ bộ nhớ toàn cục hoặc Shared Memory
                dis += (X[index, i] - cuda.const.array_like(centers)[idx_k, i])**2
            dis_arr[index][idx_k] = dis

        idx_min = 0
        for i in range(1, k):
            if dis_arr[index, i] < dis_arr[index, idx_min]:
                idx_min = i

        labels[index] = idx_min

# %%
class K_Means_OPT3:
  # init parameter of class
  def __init__(self, k):
    self.k = k
    self.num_loop = 0

  # chooose random k of center from X
  def init_center(self, X):
    return X[:self.k]

  def cal_new_center(self, X):
    # Tạo ma trận nhãn one-hot
    one_hot_labels = np.eye(self.k)[self.labels]

    # Tính toán tổng theo cụm
    cluster_sums = np.dot(one_hot_labels.T, X)

    # Đếm số điểm trong mỗi cụm
    cluster_counts = np.sum(one_hot_labels, axis=0)

    # Tránh chia cho 0
    cluster_counts[cluster_counts == 0] = 1

    # Tính trung tâm mới của các cụm
    new_centers = cluster_sums / cluster_counts[:, None]

    return new_centers

  def fit(self, X):
    # khởi tạo các mảng numpy cần thiết
    start_init = time.time()
    X = np.ascontiguousarray(X)
    self.centers = self.init_center(X);
    self.labels = np.zeros(len(X), dtype=int)
    dis_arr = np.zeros((X.shape[0], k), dtype=float)

    block_size = (32,)
    grid_size = (math.ceil(len(X) / block_size[0]),)

    # Khởi tạo các mốc thời gian
    self.assign_time = self.cal_ncenter_time = self.check_time = 0
    end_init = time.time()
    self.init_time = end_init - start_init

    while(1):
    # for i in range(2):
      self.num_loop += 1
      start_assign = time.time()

      # call kernel
      # assign_labels_opt1[grid_size, block_size](X, self.centers, self.labels, self.k, dis_arr)
      constant_array[1, 32](X, self.centers)
      assign_labels_opt2[grid_size, block_size](X, self.centers, self.labels, self.k, dis_arr)
      cuda.synchronize()

      start_cal_ncenter = time.time()
      new_centers = self.cal_new_center(X)

      start_check = time.time()
      if np.all(new_centers == self.centers):
        break
        # print("ok")
      else:
        self.centers = new_centers

      end_loop = time.time()

      self.assign_time += (start_cal_ncenter - start_assign)
      self.cal_ncenter_time += (start_check - start_cal_ncenter)
      self.check_time += (end_loop - start_check)
    return self

# %%
# small data to compile
x_test = np.random.rand(10,2)
km_test= K_Means_OPT3(k=10)
res_test = km_test.fit(x_test)

# %%
km = K_Means_OPT3(k = 20)
res_popt3 = km.fit(X)

# %% [markdown]
# #### Đánh giá

# %% [markdown]
# ##### Thời gian chạy

# %%
total_time = res_popt3.assign_time + res_popt3.cal_ncenter_time + res_popt3.check_time + res_popt3.init_time
print("Thời gian khởi tạo: ", res_popt3.init_time)
print("Thời gian phân cụm: ", res_popt3.assign_time)
print("Thời gian tính các trung tâm mới: ", res_popt3.cal_ncenter_time)
print("Thời gian kiểm tra sự thay đổi các trung tâm: ", res_popt3.check_time)
print("Tổng thời gian: ", total_time)

all_results.loc['parallel opt 3: CMEM', 'time (s)'] = total_time
all_results
# Out:
# Thời gian khởi tạo:  0.001750946044921875
# Thời gian phân cụm:  3.0616517066955566
# Thời gian tính các trung tâm mới:  1.7343754768371582
# Thời gian kiểm tra sự thay đổi các trung tâm:  0.008306503295898438
# Tổng thời gian:  4.806084632873535
#                                        time (s)
# use library                            0.622627
# sequential                           819.526603
# parallel basic                        14.162330
# parallel basic + opt cal center        2.871767
# parallel basic 2                       3.050100
# parallel opt 1: opt convert process    0.025302
# parallel opt 2: SMEM                   2.711842
# parallel opt 3: CMEM                   4.806085

# %% [markdown]
# ##### Tính đúng đắn

# %%
np.sum(res_popt3.labels == correct_labels)
# Out:
# 100000

# %% [markdown]
# ### Phiên bản tối ưu 4: Kết hợp SMEM với tối ưu quá trình chuyển đổi

# %% [markdown]
# #### Phân tích

# %% [markdown]
# Kết hợp thử các phương pháp tối ưu lại với nhau

# %% [markdown]
# #### Thiết kế

# %% [markdown]
# Ta sẽ viết lại hàm `fit` để tối ưu lại quá trình chuyển đổi và thử sử dụng  hàm `assign_label_opt1/assign_label_opt2` để thêm `centers` vào SMEM/CMEM.
# - Input: X(các điểm dữ liệu đầu vào), centers(các trung tâm), k(số cụm), dis_arr(array khoảng cách giữa 1 điểm dữ liệu và các trung tâm)
#
# (Lưu ý: Vì cài đặt trong class nên hàm `fit` sẽ có khác biệt)
# - Các bước thực hiện:
#   + Copy dữ liệu từ `X`, `centers` và `dis_arr` ở bộ nhớ của CPU/host sang `d_X`, `d_centers` và `d_dis_arr` ở bộ nhớ của GPU/device
#   + Cấp phát vùng nhớ ở GPU/device cho `d_labels`
#   + Gọi hàm kernel `assign_labels_opt1/2[grid_size, block_size](d_X, d_centers, d_labels, k, d_dis_arr)`(Hàm này được viết tương tự như phiên bản song song cơ bản)
#      + Ta thực hiện lưu dữ liệu của `centers` vào `smem_centers/cmem_centers` của  bộ nhớ SMEM/CMEM
#      + Tiếp theo tương tự như hàm `assign_label` của phiên bản song song cơ bản, tuy nhiên khi tính khoảng cách thì ta sử dụng `smem_centers/cmem_centers` thay vì `centers`
#   + Copy kết quả từ `d_labels` ở bộ nhớ của GPU/device về `labels` ở bộ nhớ của CPU/host
# - Output: Kết quả cuối cùng: Mảng `labels` xác định nhãn cho các điểm dữ liệu, mảng `centers` xác định trung tâm các cụm

# %% [markdown]
# #### Cài đặt

# %%
class K_Means_OPT4:
  # init parameter of class
  def __init__(self, k):
    self.k = k
    self.num_loop = 0

  # chooose random k of center from X
  def init_center(self, X):
    return X[:self.k]

  def cal_new_center(self, X):
    # Tạo ma trận nhãn one-hot
    one_hot_labels = np.eye(self.k)[self.labels]

    # Tính toán tổng theo cụm
    cluster_sums = np.dot(one_hot_labels.T, X)

    # Đếm số điểm trong mỗi cụm
    cluster_counts = np.sum(one_hot_labels, axis=0)

    # Tránh chia cho 0
    cluster_counts[cluster_counts == 0] = 1

    # Tính trung tâm mới của các cụm
    new_centers = cluster_sums / cluster_counts[:, None]

    return new_centers

  def fit(self, X):
    # khởi tạo các mảng numpy cần thiết
    start_init = time.time()
    X = np.ascontiguousarray(X)
    self.centers = self.init_center(X);
    # self.labels = np.zeros(len(X), dtype=int)
    # dis_arr = np.zeros((X.shape[0], k), dtype=float)

    block_size = (32,)
    grid_size = (math.ceil(len(X) / block_size[0]),)

    # Khởi tạo các mốc thời gian
    self.assign_time = self.cal_ncenter_time = self.check_time = 0

    d_X = cuda.to_device(X)
    d_dis_arr = cuda.device_array((X.shape[0], k), dtype=float)
    d_centers = cuda.to_device(self.centers)
    d_labels = cuda.device_array((X.shape[0], ), dtype=int)

    end_init = time.time()
    self.init_time = end_init - start_init

    while(1):
    # for i in range(2):
      self.num_loop += 1
      start_assign = time.time()

      # call kernel
      assign_labels_opt1[grid_size, block_size](d_X, d_centers, d_labels, k, d_dis_arr)
      cuda.synchronize()
      self.labels = d_labels.copy_to_host()

      start_cal_ncenter = time.time()
      new_centers = self.cal_new_center(X)

      start_check = time.time()
      if np.all(new_centers == self.centers):
        break
        # print("ok")
      else:
        self.centers = new_centers

      end_loop = time.time()

      self.assign_time += (start_cal_ncenter - start_assign)
      self.cal_ncenter_time += (start_check - start_cal_ncenter)
      self.check_time += (end_loop - start_check)
    return self

# %%
# small data to compile
x_test = np.random.rand(10,2)
km_test= K_Means_OPT4(k=10)
res_test = km_test.fit(x_test)

# %%
km = K_Means_OPT4(k = 20)
res_popt4 = km.fit(X)

# %% [markdown]
# #### Đánh giá

# %% [markdown]
# ##### Thời gian chạy

# %%
total_time = res_popt4 .assign_time + res_popt4.cal_ncenter_time + res_popt4.check_time + res_popt4.init_time
print("Thời gian khởi tạo: ", res_popt4.init_time)
print("Thời gian phân cụm: ", res_popt4.assign_time)
print("Thời gian tính các trung tâm mới: ", res_popt4.cal_ncenter_time)
print("Thời gian kiểm tra sự thay đổi các trung tâm: ", res_popt4.check_time)
print("Tổng thời gian: ", total_time)

all_results.loc['parallel opt 4: SMEM + opt convert process', 'time (s)'] = total_time
all_results
# Out:
# Thời gian khởi tạo:  0.011840343475341797
# Thời gian phân cụm:  0.0031075477600097656
# Thời gian tính các trung tâm mới:  0.020815372467041016
# Thời gian kiểm tra sự thay đổi các trung tâm:  2.8848648071289062e-05
# Tổng thời gian:  0.03579211235046387
#                                               time (s)
# use library                                   0.622627
# sequential                                  819.526603
# parallel basic                               14.162330
# parallel basic + opt cal center               2.871767
# parallel basic 2                              3.050100
# parallel opt 1: opt convert process           0.025302
# parallel opt 2: SMEM                          2.711842
# parallel opt 3: CMEM                          4.806085
# parallel opt 4: SMEM + opt convert process    0.035792

# %% [markdown]
# ##### Tính đúng đắn

# %%
np.sum(res_popt4.labels == correct_labels)
# Out:
# 27875

# %% [markdown]
# ### Phiên bản tối ưu 5: Dùng nstreams + Tối ưu quá trình chuyển đổi + SMEM

# %% [markdown]
# #### Phân tích

# %% [markdown]
# Ta sẽ tập trung tối ưu hóa hàm kernel `assign_labels` do hàm này chiếm thời gian chạy nhiều nhất. Thử sử dụng nstreams để thực hiện từng phần dữ liệu của `X`

# %% [markdown]
# #### Thiết kế

# %% [markdown]
# Ta sẽ viết lại hàm `fit` để tối ưu lại quá trình chuyển đổi và dùng thử nstreams
# - Input: X(các điểm dữ liệu đầu vào), centers(các trung tâm), k(số cụm), dis_arr(array khoảng cách giữa 1 điểm dữ liệu và các trung tâm)
#
# (Lưu ý: Vì cài đặt trong class nên hàm `fit` sẽ có khác biệt)
# - Các bước thực hiện:
#   + Copy dữ liệu từ `X`, `centers` và `dis_arr` ở bộ nhớ của CPU/host sang `d_X`, `d_centers` và `d_dis_arr` ở bộ nhớ của GPU/device
#   + Cấp phát vùng nhớ ở GPU/device cho `d_labels`
#   + Khởi tạo danh sách n stream
#   + Gọi hàm kernel `assign_labels[grid_size, block_size, stream](d_X, d_centers, d_labels, k, d_dis_arr)`(Hàm này được viết tương tự như phiên bản song song cơ bản), tuy nhiên sẽ sử dụng `start/end` giúp phân vùng dữ liệu của `d_X`, `d_centers` và `d_dis_arr` được tính bởi số lượng n stream
#      + Ta thực hiện lưu dữ liệu của `centers` vào `smem_centers` của  bộ nhớ SMEM
#      + Tiếp theo tương tự như hàm `assign_label` của phiên bản song song cơ bản, tuy nhiên khi tính khoảng cách thì ta sử dụng `smem_centers` thay vì `centers`
#   + Đồng bộ lại các stream đã chạy
#   + Copy kết quả từ `d_labels` ở bộ nhớ của GPU/device về `labels` ở bộ nhớ của CPU/host
# - Output: Kết quả cuối cùng: Mảng `labels` xác định nhãn cho các điểm dữ liệu, mảng `centers` xác định trung tâm các cụm

# %% [markdown]
# #### Cài đặt

# %%
class K_Means_OPT5:
  # init parameter of class
  def __init__(self, k):
    self.k = k
    self.num_loop = 0

  # chooose random k of center from X
  def init_center(self, X):
    return X[:self.k]

  def cal_new_center(self, X):
    # Tạo ma trận nhãn one-hot
    one_hot_labels = np.eye(self.k)[self.labels]

    # Tính toán tổng theo cụm
    cluster_sums = np.dot(one_hot_labels.T, X)

    # Đếm số điểm trong mỗi cụm
    cluster_counts = np.sum(one_hot_labels, axis=0)

    # Tránh chia cho 0
    cluster_counts[cluster_counts == 0] = 1

    # Tính trung tâm mới của các cụm
    new_centers = cluster_sums / cluster_counts[:, None]

    return new_centers

  def fit(self, X):
    # khởi tạo các mảng numpy cần thiết
    start_init = time.time()
    X = np.ascontiguousarray(X)
    self.centers = self.init_center(X);
    self.labels = np.zeros(len(X), dtype=int)
    # dis_arr = np.zeros((X.shape[0], k), dtype=float)

    block_size = (32,)
    grid_size = (math.ceil(len(X) / block_size[0]),)

    # Khởi tạo các mốc thời gian
    self.assign_time = self.cal_ncenter_time = self.check_time = 0
    end_init = time.time()
    self.init_time = end_init - start_init

    while(1):
    # for i in range(2):
      self.num_loop += 1
      start_assign = time.time()
      # Số lượng stream
      num_streams = 4
      # Tạo danh sách các stream
      streams = [cuda.stream() for _ in range(num_streams)]
      # # call kernel
      # d_X = cuda.to_device(X)
      # d_dis_arr = cuda.to_device(dis_arr)
      d_centers = cuda.to_device(self.centers)
      # d_labels = cuda.device_array((X.shape[0], ), dtype=self.labels.dtype)
      elements_per_stream = math.ceil(len(X) / num_streams)
      for i, stream in enumerate(streams):
        # Tính toán trên stream thứ i
        start = i * elements_per_stream
        end = min((i + 1) * elements_per_stream, len(X))
        length = end - start
        # call kernel
        d_X = cuda.to_device(X, stream=stream)
        d_dis_arr = cuda.device_array((length, k), dtype=float)
        d_labels = cuda.device_array((length, ), dtype=int)
        assign_labels_opt1[grid_size, block_size, stream](d_X[start:end], d_centers, d_labels, k, d_dis_arr)
        self.labels[start:end] = d_labels.copy_to_host(stream=stream)

      cuda.synchronize()
      # Đồng bộ hóa tất cả các stream
      for stream in streams:
          stream.synchronize()

      start_cal_ncenter = time.time()
      new_centers = self.cal_new_center(X)

      start_check = time.time()
      if np.all(new_centers == self.centers):
        break
        # print("ok")
      else:
        self.centers = new_centers

      end_loop = time.time()

      self.assign_time += (start_cal_ncenter - start_assign)
      self.cal_ncenter_time += (start_check - start_cal_ncenter)
      self.check_time += (end_loop - start_check)
    return self

# %%
# small data to compile
x_test = np.random.rand(10,2)
km_test= K_Means_OPT5(k=10)
res_test = km_test.fit(x_test)

# %%
km = K_Means_OPT5(k = 20)
res_popt5 = km.fit(X)

# %% [markdown]
# #### Đánh giá

# %% [markdown]
# ##### Thời gian chạy

# %%
total_time = res_popt5.assign_time + res_popt5.cal_ncenter_time + res_popt5.check_time + res_popt5.init_time
print("Thời gian khởi tạo: ", res_popt5.init_time)
print("Thời gian phân cụm: ", res_popt5.assign_time)
print("Thời gian tính các trung tâm mới: ", res_popt5.cal_ncenter_time)
print("Thời gian kiểm tra sự thay đổi các trung tâm: ", res_popt5.check_time)
print("Tổng thời gian: ", total_time)

all_results.loc['parallel opt 5: nstream + SMEM + opt convert process', 'time (s)'] = total_time
all_results
# Out:
# Thời gian khởi tạo:  0.0001392364501953125
# Thời gian phân cụm:  2.028635025024414
# Thời gian tính các trung tâm mới:  1.1659574508666992
# Thời gian kiểm tra sự thay đổi các trung tâm:  0.002090930938720703
# Tổng thời gian:  3.1968226432800293
#                                                       time (s)
# use library                                           0.622627
# sequential                                          819.526603
# parallel basic                                       14.162330
# parallel basic + opt cal center                       2.871767
# parallel basic 2                                      3.050100
# parallel opt 1: opt convert process                   0.025302
# parallel opt 2: SMEM                                  2.711842
# parallel opt 3: CMEM                                  4.806085
# parallel opt 4: SMEM + opt convert process            0.035792
# parallel opt 5: nstream + SMEM + opt convert pr...    3.196823

# %% [markdown]
# ###### Phân tích thời gian chạy với NVIDIA Nsight Systems

# %%
# !gdown https://drive.google.com/uc?id=1PoMw6Z9VwzoaIiL1-o-nT1q7e7bRJhNh
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1PoMw6Z9VwzoaIiL1-o-nT1q7e7bRJhNh
# From (redirected): https://drive.google.com/uc?id=1PoMw6Z9VwzoaIiL1-o-nT1q7e7bRJhNh&confirm=t&uuid=46c92c96-1bcb-4945-bbbb-5e8b9612640b
# To: /content/parallel1.py
# 100% 4.19k/4.19k [00:00<00:00, 15.2MB/s]

# %%
# Here is the command to install Nsight system on Colab. You just need to run the cell.
# !wget https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64/nsight-systems-2023.2.3_2023.2.3.1001-1_amd64.deb
# !apt update
# !apt install ./nsight-systems-2023.2.3_2023.2.3.1001-1_amd64.deb
# !apt --fix-broken install
# Out:
# --2024-06-04 03:08:10--  https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64/nsight-systems-2023.2.3_2023.2.3.1001-1_amd64.deb
# Resolving developer.download.nvidia.com (developer.download.nvidia.com)... 152.199.39.144
# Connecting to developer.download.nvidia.com (developer.download.nvidia.com)|152.199.39.144|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 317705436 (303M) [application/x-deb]
# Saving to: ‘nsight-systems-2023.2.3_2023.2.3.1001-1_amd64.deb’
#
# nsight-systems-2023 100%[===================>] 302.99M   209MB/s    in 1.5s
#
# 2024-06-04 03:08:11 (209 MB/s) - ‘nsight-systems-2023.2.3_2023.2.3.1001-1_amd64.deb’ saved [317705436/317705436]
#
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,626 B]
# Hit:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:3 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:4 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:5 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Hit:6 https://ppa.launchpadcontent.net/c2d4u.team/c2d4u4.0+/ubuntu jammy InRelease
# Hit:7 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:8 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Get:9 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,085 kB]
# Hit:10 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Hit:11 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Get:12 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [2,129 kB]
# Get:13 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,377 kB]
# Fetched 4,852 kB in 14s (342 kB/s)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# 45 packages can be upgraded. Run 'apt list --upgradable' to see them.
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# Note, selecting 'nsight-systems-2023.2.3' instead of './nsight-systems-2023.2.3_2023.2.3.1001-1_amd64.deb'
# The following additional packages will be installed:
#   libtinfo5 libxcb-icccm4 libxcb-image0 libxcb-keysyms1 libxcb-render-util0 libxcb-util1
#   libxcb-xinerama0 libxcb-xinput0 libxcb-xkb1 libxkbcommon-x11-0 libxtst6
# The following NEW packages will be installed:
#   libtinfo5 libxcb-icccm4 libxcb-image0 libxcb-keysyms1 libxcb-render-util0 libxcb-util1
#   libxcb-xinerama0 libxcb-xinput0 libxcb-xkb1 libxkbcommon-x11-0 libxtst6 nsight-systems-2023.2.3
# 0 upgraded, 12 newly installed, 0 to remove and 45 not upgraded.
# Need to get 318 MB of archives.
# After this operation, 1,269 kB of additional disk space will be used.
# Get:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  nsight-systems-2023.2.3 2023.2.3.1001-32894139v0 [318 MB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libtinfo5 amd64 6.3-2ubuntu0.1 [100 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-xinerama0 amd64 1.14-3ubuntu3 [5,414 B]
# Get:4 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-xinput0 amd64 1.14-3ubuntu3 [34.3 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-xkb1 amd64 1.14-3ubuntu3 [32.8 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxkbcommon-x11-0 amd64 1.4.0-1 [14.4 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxtst6 amd64 2:1.2.3-1build4 [13.4 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-icccm4 amd64 0.4.1-1.1build2 [11.5 kB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-util1 amd64 0.4.0-1build2 [11.4 kB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-image0 amd64 0.4.0-2 [11.5 kB]
# Get:11 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-keysyms1 amd64 0.4.0-1build3 [8,746 B]
# Get:12 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-render-util0 amd64 0.3.9-1build3 [10.3 kB]
# Fetched 318 MB in 4s (76.9 MB/s)
# Selecting previously unselected package libtinfo5:amd64.
# (Reading database ... 121918 files and directories currently installed.)
# Preparing to unpack .../00-libtinfo5_6.3-2ubuntu0.1_amd64.deb ...
# Unpacking libtinfo5:amd64 (6.3-2ubuntu0.1) ...
# Selecting previously unselected package libxcb-xinerama0:amd64.
# Preparing to unpack .../01-libxcb-xinerama0_1.14-3ubuntu3_amd64.deb ...
# Unpacking libxcb-xinerama0:amd64 (1.14-3ubuntu3) ...
# Selecting previously unselected package libxcb-xinput0:amd64.
# Preparing to unpack .../02-libxcb-xinput0_1.14-3ubuntu3_amd64.deb ...
# Unpacking libxcb-xinput0:amd64 (1.14-3ubuntu3) ...
# Selecting previously unselected package libxcb-xkb1:amd64.
# Preparing to unpack .../03-libxcb-xkb1_1.14-3ubuntu3_amd64.deb ...
# Unpacking libxcb-xkb1:amd64 (1.14-3ubuntu3) ...
# Selecting previously unselected package libxkbcommon-x11-0:amd64.
# Preparing to unpack .../04-libxkbcommon-x11-0_1.4.0-1_amd64.deb ...
# Unpacking libxkbcommon-x11-0:amd64 (1.4.0-1) ...
# Selecting previously unselected package libxtst6:amd64.
# Preparing to unpack .../05-libxtst6_2%3a1.2.3-1build4_amd64.deb ...
# Unpacking libxtst6:amd64 (2:1.2.3-1build4) ...
# Selecting previously unselected package libxcb-icccm4:amd64.
# Preparing to unpack .../06-libxcb-icccm4_0.4.1-1.1build2_amd64.deb ...
# Unpacking libxcb-icccm4:amd64 (0.4.1-1.1build2) ...
# Selecting previously unselected package libxcb-util1:amd64.
# Preparing to unpack .../07-libxcb-util1_0.4.0-1build2_amd64.deb ...
# Unpacking libxcb-util1:amd64 (0.4.0-1build2) ...
# Selecting previously unselected package libxcb-image0:amd64.
# Preparing to unpack .../08-libxcb-image0_0.4.0-2_amd64.deb ...
# Unpacking libxcb-image0:amd64 (0.4.0-2) ...
# Selecting previously unselected package libxcb-keysyms1:amd64.
# Preparing to unpack .../09-libxcb-keysyms1_0.4.0-1build3_amd64.deb ...
# Unpacking libxcb-keysyms1:amd64 (0.4.0-1build3) ...
# Selecting previously unselected package libxcb-render-util0:amd64.
# Preparing to unpack .../10-libxcb-render-util0_0.3.9-1build3_amd64.deb ...
# Unpacking libxcb-render-util0:amd64 (0.3.9-1build3) ...
# Selecting previously unselected package nsight-systems-2023.2.3.
# Preparing to unpack .../11-nsight-systems-2023.2.3_2023.2.3.1001-32894139v0_amd64.deb ...
# Unpacking nsight-systems-2023.2.3 (2023.2.3.1001-32894139v0) ...
# Setting up libxcb-xinput0:amd64 (1.14-3ubuntu3) ...
# Setting up libxtst6:amd64 (2:1.2.3-1build4) ...
# Setting up libxcb-keysyms1:amd64 (0.4.0-1build3) ...
# Setting up libxcb-render-util0:amd64 (0.3.9-1build3) ...
# Setting up libxcb-icccm4:amd64 (0.4.1-1.1build2) ...
# Setting up libxcb-util1:amd64 (0.4.0-1build2) ...
# Setting up libxcb-xkb1:amd64 (1.14-3ubuntu3) ...
# Setting up libxcb-image0:amd64 (0.4.0-2) ...
# Setting up libxcb-xinerama0:amd64 (1.14-3ubuntu3) ...
# Setting up libxkbcommon-x11-0:amd64 (1.4.0-1) ...
# Setting up libtinfo5:amd64 (6.3-2ubuntu0.1) ...
# Setting up nsight-systems-2023.2.3 (2023.2.3.1001-32894139v0) ...
# update-alternatives: using /opt/nvidia/nsight-systems/2023.2.3/target-linux-x64/nsys to provide /usr/local/bin/nsys (nsys) in auto mode
# update-alternatives: using /opt/nvidia/nsight-systems/2023.2.3/host-linux-x64/nsys-ui to provide /usr/local/bin/nsys-ui (nsys-ui) in auto mode
# Processing triggers for libc-bin (2.35-0ubuntu3.4) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# 0 upgraded, 0 newly installed, 0 to remove and 46 not upgraded.

# %%
# !nsys profile /usr/local/bin/python ./parallel1.py
# Out:
# Generating '/tmp/nsys-report-a329.qdstrm'
# [1/1] [========================100%] report1.nsys-rep
# Generated:
#     /content/report1.nsys-rep

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Ta thấy quá trình thực hiện copy dữ liệu và thực thi kernel không được overlap với nhau. Dẫn đến phiên bản sử dụng stream không đạt được kỳ vọng rút ngắn thời gian.

# %% [markdown]
# ##### Tính đúng đắn

# %%
np.sum(res_popt5.labels == correct_labels)
# Out:
# 100000

# %% [markdown]
# ### Phiên bản tối ưu 6: Kết hợp CMEM với tối ưu quá trình chuyển đổi

# %% [markdown]
# #### Phân tích

# %% [markdown]
# Kết hợp thử các phương pháp tối ưu lại với nhau

# %% [markdown]
# #### Thiết kế

# %% [markdown]
# Ta sẽ viết lại hàm `fit` để tối ưu lại quá trình chuyển đổi và thử sử dụng  hàm `assign_label_opt1/assign_label_opt2` để thêm `centers` vào SMEM/CMEM.
# - Input: X(các điểm dữ liệu đầu vào), centers(các trung tâm), k(số cụm), dis_arr(array khoảng cách giữa 1 điểm dữ liệu và các trung tâm)
#
# (Lưu ý: Vì cài đặt trong class nên hàm `fit` sẽ có khác biệt)
# - Các bước thực hiện:
#   + Copy dữ liệu từ `X`, `centers` và `dis_arr` ở bộ nhớ của CPU/host sang `d_X`, `d_centers` và `d_dis_arr` ở bộ nhớ của GPU/device
#   + Cấp phát vùng nhớ ở GPU/device cho `d_labels`
#   + Gọi hàm kernel `assign_labels_opt1/2[grid_size, block_size](d_X, d_centers, d_labels, k, d_dis_arr)`(Hàm này được viết tương tự như phiên bản song song cơ bản)
#      + Ta thực hiện lưu dữ liệu của `centers` vào `smem_centers/cmem_centers` của  bộ nhớ SMEM/CMEM
#      + Tiếp theo tương tự như hàm `assign_label` của phiên bản song song cơ bản, tuy nhiên khi tính khoảng cách thì ta sử dụng `smem_centers/cmem_centers` thay vì `centers`
#   + Copy kết quả từ `d_labels` ở bộ nhớ của GPU/device về `labels` ở bộ nhớ của CPU/host
# - Output: Kết quả cuối cùng: Mảng `labels` xác định nhãn cho các điểm dữ liệu, mảng `centers` xác định trung tâm các cụm

# %% [markdown]
# #### Cài đặt

# %%
class K_Means_OPT6:
  # init parameter of class
  def __init__(self, k):
    self.k = k
    self.num_loop = 0

  # chooose random k of center from X
  def init_center(self, X):
    return X[:self.k]

  def cal_new_center(self, X):
    # Tạo ma trận nhãn one-hot
    one_hot_labels = np.eye(self.k)[self.labels]

    # Tính toán tổng theo cụm
    cluster_sums = np.dot(one_hot_labels.T, X)

    # Đếm số điểm trong mỗi cụm
    cluster_counts = np.sum(one_hot_labels, axis=0)

    # Tránh chia cho 0
    cluster_counts[cluster_counts == 0] = 1

    # Tính trung tâm mới của các cụm
    new_centers = cluster_sums / cluster_counts[:, None]

    return new_centers

  def fit(self, X):
    # khởi tạo các mảng numpy cần thiết
    start_init = time.time()
    X = np.ascontiguousarray(X)
    self.centers = self.init_center(X);
    # self.labels = np.zeros(len(X), dtype=int)
    # dis_arr = np.zeros((X.shape[0], k), dtype=float)

    block_size = (32,)
    grid_size = (math.ceil(len(X) / block_size[0]),)

    # Khởi tạo các mốc thời gian
    self.assign_time = self.cal_ncenter_time = self.check_time = 0

    d_X = cuda.to_device(X)
    d_dis_arr = cuda.device_array((X.shape[0], k), dtype=float)
    d_centers = cuda.to_device(self.centers)
    d_labels = cuda.device_array((X.shape[0], ), dtype=int)

    end_init = time.time()
    self.init_time = end_init - start_init

    while(1):
    # for i in range(2):
      self.num_loop += 1
      start_assign = time.time()

      # call kernel
      constant_array[1, 32](X, self.centers)
      assign_labels_opt2[grid_size, block_size](d_X, d_centers, d_labels, k, d_dis_arr)
      cuda.synchronize()
      self.labels = d_labels.copy_to_host()

      start_cal_ncenter = time.time()
      new_centers = self.cal_new_center(X)

      start_check = time.time()
      if np.all(new_centers == self.centers):
        break
        # print("ok")
      else:
        self.centers = new_centers

      end_loop = time.time()

      self.assign_time += (start_cal_ncenter - start_assign)
      self.cal_ncenter_time += (start_check - start_cal_ncenter)
      self.check_time += (end_loop - start_check)
    return self

# %%
# small data to compile
x_test = np.random.rand(10,2)
km_test= K_Means_OPT6(k=10)
res_test = km_test.fit(x_test)

# %%
km = K_Means_OPT6(k = 20)
res_popt6 = km.fit(X)

# %% [markdown]
# #### Đánh giá

# %% [markdown]
# ##### Thời gian chạy

# %%
total_time = res_popt6.assign_time + res_popt6.cal_ncenter_time + res_popt6.check_time + res_popt6.init_time
print("Thời gian khởi tạo: ", res_popt6.init_time)
print("Thời gian phân cụm: ", res_popt6.assign_time)
print("Thời gian tính các trung tâm mới: ", res_popt6.cal_ncenter_time)
print("Thời gian kiểm tra sự thay đổi các trung tâm: ", res_popt6.check_time)
print("Tổng thời gian: ", total_time)

all_results.loc['parallel opt 6: CMEM + opt convert process', 'time (s)'] = total_time
all_results
# Out:
# Thời gian khởi tạo:  0.0051517486572265625
# Thời gian phân cụm:  0.010790348052978516
# Thời gian tính các trung tâm mới:  0.014824628829956055
# Thời gian kiểm tra sự thay đổi các trung tâm:  2.8848648071289062e-05
# Tổng thời gian:  0.030795574188232422
#                                                       time (s)
# use library                                           0.622627
# sequential                                          819.526603
# parallel basic                                       14.162330
# parallel basic + opt cal center                       2.871767
# parallel basic 2                                      3.050100
# parallel opt 1: opt convert process                   0.025302
# parallel opt 2: SMEM                                  2.711842
# parallel opt 3: CMEM                                  4.806085
# parallel opt 4: SMEM + opt convert process            0.035792
# parallel opt 5: nstream + SMEM + opt convert pr...    3.196823
# parallel opt 6: CMEM + opt convert process            0.030796

# %% [markdown]
# ##### Tính đúng đắn

# %%
np.sum(res_popt6.labels == correct_labels)
# Out:
# 27875

# %% [markdown]
# ### Phiên bản tối ưu 7: Kết hợp CMEM, nstream với tối ưu quá trình chuyển đổi

# %% [markdown]
# #### Phân tích

# %% [markdown]
# Kết hợp thử các phương pháp tối ưu lại với nhau

# %% [markdown]
# #### Thiết kế

# %% [markdown]
# Ta sẽ viết lại hàm `fit` để tối ưu lại quá trình chuyển đổi và dùng thử nstreams
# - Input: X(các điểm dữ liệu đầu vào), centers(các trung tâm), k(số cụm), dis_arr(array khoảng cách giữa 1 điểm dữ liệu và các trung tâm)
#
# (Lưu ý: Vì cài đặt trong class nên hàm `fit` sẽ có khác biệt)
# - Các bước thực hiện:
#   + Copy dữ liệu từ `X`, `centers` và `dis_arr` ở bộ nhớ của CPU/host sang `d_X`, `d_centers` và `d_dis_arr` ở bộ nhớ của GPU/device
#   + Cấp phát vùng nhớ ở GPU/device cho `d_labels`
#   + Khởi tạo danh sách n stream
#   + Gọi hàm kernel `assign_labels[grid_size, block_size, stream](d_X, d_centers, d_labels, k, d_dis_arr)`(Hàm này được viết tương tự như phiên bản song song cơ bản), tuy nhiên sẽ sử dụng `start/end` giúp phân vùng dữ liệu của `d_X`, `d_centers` và `d_dis_arr` được tính bởi số lượng n stream
#      + Ta thực hiện lưu dữ liệu của `centers` vào `cmem_centers` của  bộ nhớ CMEM
#      + Tiếp theo tương tự như hàm `assign_label` của phiên bản song song cơ bản, tuy nhiên khi tính khoảng cách thì ta sử dụng `cmem_centers` thay vì `centers`
#   + Đồng bộ lại các stream đã chạy
#   + Copy kết quả từ `d_labels` ở bộ nhớ của GPU/device về `labels` ở bộ nhớ của CPU/host
# - Output: Kết quả cuối cùng: Mảng `labels` xác định nhãn cho các điểm dữ liệu, mảng `centers` xác định trung tâm các cụm

# %% [markdown]
# #### Cài đặt

# %%
class K_Means_OPT7:
  # init parameter of class
  def __init__(self, k):
    self.k = k
    self.num_loop = 0

  # chooose random k of center from X
  def init_center(self, X):
    return X[:self.k]

  def cal_new_center(self, X):
    # Tạo ma trận nhãn one-hot
    one_hot_labels = np.eye(self.k)[self.labels]

    # Tính toán tổng theo cụm
    cluster_sums = np.dot(one_hot_labels.T, X)

    # Đếm số điểm trong mỗi cụm
    cluster_counts = np.sum(one_hot_labels, axis=0)

    # Tránh chia cho 0
    cluster_counts[cluster_counts == 0] = 1

    # Tính trung tâm mới của các cụm
    new_centers = cluster_sums / cluster_counts[:, None]

    return new_centers

  def fit(self, X):
    # khởi tạo các mảng numpy cần thiết
    start_init = time.time()
    X = np.ascontiguousarray(X)
    self.centers = self.init_center(X);
    self.labels = np.zeros(len(X), dtype=int)
    dis_arr = np.zeros((X.shape[0], k), dtype=float)

    block_size = (32,)
    grid_size = (math.ceil(len(X) / block_size[0]),)

    # Khởi tạo các mốc thời gian
    self.assign_time = self.cal_ncenter_time = self.check_time = 0
    end_init = time.time()
    self.init_time = end_init - start_init

    while(1):
    # for i in range(2):
      self.num_loop += 1
      start_assign = time.time()
      # Số lượng stream
      num_streams = 4
      # Tạo danh sách các stream
      streams = [cuda.stream() for _ in range(num_streams)]
      # # call kernel
      # d_X = cuda.to_device(X)
      # d_dis_arr = cuda.to_device(dis_arr)
      d_centers = cuda.to_device(self.centers)
      # d_labels = cuda.device_array((X.shape[0], ), dtype=self.labels.dtype)
      elements_per_stream = math.ceil(len(X) / num_streams)
      constant_array[1, 32](X, self.centers)
      for i, stream in enumerate(streams):
        # Tính toán trên stream thứ i
        start = i * elements_per_stream
        end = min((i + 1) * elements_per_stream, len(X))
        length = end - start
        # call kernel
        d_X = cuda.to_device(X[start:end], stream=stream)
        d_dis_arr = cuda.to_device(dis_arr[start:end], stream=stream)
        d_labels = cuda.device_array((length, ), dtype=self.labels.dtype, stream=stream)
        assign_labels_opt2[grid_size, block_size, stream](d_X, d_centers, d_labels, k, d_dis_arr)
        self.labels[start:end] = d_labels.copy_to_host(stream=stream)

      cuda.synchronize()
      # Đồng bộ hóa tất cả các stream
      for stream in streams:
          stream.synchronize()

      start_cal_ncenter = time.time()
      new_centers = self.cal_new_center(X)

      start_check = time.time()
      if np.all(new_centers == self.centers):
        break
        # print("ok")
      else:
        self.centers = new_centers

      end_loop = time.time()

      self.assign_time += (start_cal_ncenter - start_assign)
      self.cal_ncenter_time += (start_check - start_cal_ncenter)
      self.check_time += (end_loop - start_check)
    return self

# %%
# small data to compile
x_test = np.random.rand(10,2)
km_test= K_Means_OPT7(k=10)
res_test = km_test.fit(x_test)

# %%
km = K_Means_OPT7(k = 20)
res_popt7 = km.fit(X)

# %% [markdown]
# #### Đánh giá

# %% [markdown]
# ##### Thời gian chạy

# %%
total_time = res_popt7.assign_time + res_popt7.cal_ncenter_time + res_popt7.check_time + res_popt7.init_time
print("Thời gian khởi tạo: ", res_popt7.init_time)
print("Thời gian phân cụm: ", res_popt7.assign_time)
print("Thời gian tính các trung tâm mới: ", res_popt7.cal_ncenter_time)
print("Thời gian kiểm tra sự thay đổi các trung tâm: ", res_popt7.check_time)
print("Tổng thời gian: ", total_time)

all_results.loc['parallel opt 7: nstream + CMEM + opt convert process', 'time (s)'] = total_time
all_results
# Out:
# Thời gian khởi tạo:  0.0031824111938476562
# Thời gian phân cụm:  3.1224188804626465
# Thời gian tính các trung tâm mới:  1.965207815170288
# Thời gian kiểm tra sự thay đổi các trung tâm:  0.017100811004638672
# Tổng thời gian:  5.107909917831421
#                                                       time (s)
# use library                                           0.622627
# sequential                                          819.526603
# parallel basic                                       14.162330
# parallel basic + opt cal center                       2.871767
# parallel basic 2                                      3.050100
# parallel opt 1: opt convert process                   0.025302
# parallel opt 2: SMEM                                  2.711842
# parallel opt 3: CMEM                                  4.806085
# parallel opt 4: SMEM + opt convert process            0.035792
# parallel opt 5: nstream + SMEM + opt convert pr...    3.196823
# parallel opt 6: CMEM + opt convert process            0.030796
# parallel opt 7: nstream + CMEM + opt convert pr...    5.107910

# %% [markdown]
# ##### Tính đúng đắn

# %%
np.sum(res_popt7.labels == correct_labels)
# Out:
# 100000

# %% [markdown]
# ### **Nhận xét:** (Cho các phiên bản tối ưu)
# + Đối với bộ dữ liệu gồm 20000 sample thì ta thấy:
#   + Khi thực hiện tối ưu quá trình chuyển đổi thì thời gian luôn luôn giảm
#   + SMEM có thời gian chạy nhanh hơn CMEM (Vì CMEM cần phải thực hiện 1 hàm riêng để hình thành CMEM cho giá trị cần lưu)
#   + Về SMEM và nstream thì thời gian cũng có giảm nhưng giảm không đáng kể, tuy nhiên thì lại kém hơn khi chỉ tối ưu quá trình chuyển đổi
# + Đối với bộ dữ liệu gồm 100000 sample thì ta thấy:
#   + SMEM đã có thời gian chạy nhanh hơn tuy nhiên vẫn chậm hơn 1 ít so với khi chỉ tối ưu quá trình chuyển đổi
#
# Từ đó, ta rút ra kết luận:
# + Luôn luôn thực hiện quá trình chuyển đổi để giảm tốc độ thực thi
# + Sử dụng SMEM  khi có bộ dữ liệu lớn, không nên sử dụng với bộ dữ liệu nhỏ
